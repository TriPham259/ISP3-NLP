# %%
import pandas as pd
import numpy as np

from sklearn.pipeline import Pipeline
from gensim.models import word2vec
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score, KFold

# %% [markdown]
# ## Dataset

# %%
from sklearn.datasets import fetch_20newsgroups
train_raw_df = fetch_20newsgroups(subset='train', data_home='./scikit_learn_data')
x_train = train_raw_df.data
y_train = train_raw_df.target

# %% [markdown]
# Now we write the required functions to process our dataset.

# %%
# library for cleaning texts
import re

# download the list of all non-significant/irrelevant words
import nltk
nltk.download('stopwords', download_dir='/usr/local/share/nltk_data')
from nltk.corpus import stopwords

# library for stemming (filter out the base form of the words)
from nltk.stem.porter import PorterStemmer

# cleaning one sentence of the dataset
def cleaning(sentence):
    # replace all characters except letters in dataset with ' '
    tokens = re.sub('[^a-zA-Z]', ' ', sentence)

    # change all letters to lower case
    tokens = tokens.lower()

    # split the sentence into a list of words
    tokens = tokens.split()
    
    # remove irrelevant words
    ps = PorterStemmer()
    tokens = [ps.stem(word) for word in tokens if not word in set(stopwords.words('english'))]
    
    # return the sentence as a list of words
    return tokens

# create a list of lists containing words from each sentence
def preprocess_wv(x):
    corpus = [cleaning(sentence) for sentence in x]   
    return corpus

# create a corpus of cleaned sentences for BoW models
def preprocess_bow(x):
    corpus = [' '.join(cleaning(sentence)) for sentence in x]   
    return corpus

# build BoW models from the corpus
def build_model(mode):
    # choose which type of model to use
    vect = None
    if mode == 'count':
        vect = CountVectorizer()
    elif mode == 'tf':
        vect = TfidfVectorizer(use_idf=False, norm='l2')
    else:
        raise ValueError('Mode should be either count or tfidf')
    
    return Pipeline([
        ('vect', vect),
        ('clf' , LogisticRegression(solver='newton-cg',n_jobs=-1))
    ])

# process our dataset
def pipeline(x, y, mode):
    processed_x = preprocess_bow(x)
    
    model_pipeline = build_model(mode)
    cv = KFold(n_splits=5, shuffle=True)
    
    scores = cross_val_score(model_pipeline, processed_x, y, cv=cv, scoring='accuracy')
    print("Accuracy: %0.4f (+/- %0.4f)" % (scores.mean(), scores.std() * 2))
    
    return model_pipeline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /usr/local/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Training the Word2Vec model

# %% [markdown]
# Let's build the vocabulary and train the Word2Vec model.

# %%
documents = preprocess_wv(x_train)
model = word2vec.Word2Vec(documents, size=100, window=10, min_count=2, workers=4)
model.train(documents, total_examples=len(documents), epochs=10)
# Out:
# (19807064, 21334320)

# %% [markdown]
# ## Let's look at some output

# %% [markdown]
# This is the vocabulary of our dataset:

# %%
model.wv.vocab
# Out:
# {'lerxst': <gensim.models.keyedvectors.Vocab at 0x1a2ce967f0>,
#  'wam': <gensim.models.keyedvectors.Vocab at 0x1a2ce965c0>,
#  'umd': <gensim.models.keyedvectors.Vocab at 0x1a2cead9b0>,
#  'edu': <gensim.models.keyedvectors.Vocab at 0x1a2cead358>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x1a2cead4e0>,
#  'subject': <gensim.models.keyedvectors.Vocab at 0x1a2cead5c0>,
#  'car': <gensim.models.keyedvectors.Vocab at 0x1a2cead128>,
#  'nntp': <gensim.models.keyedvectors.Vocab at 0x1a2ceadd30>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x1a2ceadc18>,
#  'host': <gensim.models.keyedvectors.Vocab at 0x1a2cea89b0>,
#  'rac': <gensim.models.keyedvectors.Vocab at 0x1a2cea8048>,
#  'organ': <gensim.models.keyedvectors.Vocab at 0x1a2cea8278>,
#  'univers': <gensim.models.keyedvectors.Vocab at 0x1a2cec01d0>,
#  'maryland': <gensim.models.keyedvectors.Vocab at 0x1a2cec0f98>,
#  'colleg': <gensim.models.keyedvectors.Vocab at 0x1a2cec0ef0>,
#  'park': <gensim.models.keyedvectors.Vocab at 0x1a2cec0fd0>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x1a2cef0828>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x1a2cef02b0>,
#  'anyon': <gensim.models.keyedvectors.Vocab at 0x1a2cef0d30>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x1a2cef0550>,
#  'enlighten': <gensim.models.keyedvectors.Vocab at 0x1a2cef0be0>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x1a2cef09e8>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x1a2cef0438>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x1a2cef0b38>,
#  'sport': <gensim.models.keyedvectors.Vocab at 0x1a2ceec3c8>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x1a2ceec4e0>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x1a2ceec208>,
#  'earli': <gensim.models.keyedvectors.Vocab at 0x1a2ceec6a0>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x1a2ceec128>,
#  'bricklin': <gensim.models.keyedvectors.Vocab at 0x1a2ceec4a8>,
#  'realli': <gensim.models.keyedvectors.Vocab at 0x1a2ceec0b8>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x1a2ceec240>,
#  'addit': <gensim.models.keyedvectors.Vocab at 0x1a2ceec1d0>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x1a2ceec588>,
#  'bumper': <gensim.models.keyedvectors.Vocab at 0x1a2ceec320>,
#  'separ': <gensim.models.keyedvectors.Vocab at 0x1a2ceec748>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x1a2ceec400>,
#  'bodi': <gensim.models.keyedvectors.Vocab at 0x1a2ceec198>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x1a2ceec668>,
#  'tellm': <gensim.models.keyedvectors.Vocab at 0x1a2ceec0f0>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x1a2ceec358>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x1a2ceec080>,
#  'engin': <gensim.models.keyedvectors.Vocab at 0x1a2ceec160>,
#  'spec': <gensim.models.keyedvectors.Vocab at 0x1a2ceec518>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x1a2ceec7b8>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x1a2cf03048>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x1a2cf050b8>,
#  'histori': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e128>,
#  'whatev': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e4a8>,
#  'info': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e6a0>,
#  'funki': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e940>,
#  'pleas': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ec18>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x1a2cf0eac8>,
#  'mail': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ecc0>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ea58>,
#  'il': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e240>,
#  'brought': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ef60>,
#  'neighborhood': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ee10>,
#  'guykuo': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e6d8>,
#  'carson': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e828>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e278>,
#  'washington': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e160>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ea20>,
#  'kuo': <gensim.models.keyedvectors.Vocab at 0x1a2cf0eeb8>,
#  'si': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e438>,
#  'clock': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ec88>,
#  'poll': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e0f0>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x1a2cf0eb38>,
#  'summari': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ecf8>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e2e8>,
#  'keyword': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e0b8>,
#  'acceler': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e470>,
#  'upgrad': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e908>,
#  'articl': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ea90>,
#  'shelley': <gensim.models.keyedvectors.Vocab at 0x1a2cf0eba8>,
#  'innc': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e710>,
#  'fair': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e9e8>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e518>,
#  'brave': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e630>,
#  'soul': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e668>,
#  'oscil': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e7f0>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e400>,
#  'experi': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ee80>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e4e0>,
#  'brief': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e080>,
#  'messag': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e7b8>,
#  'detail': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e9b0>,
#  'procedur': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ef98>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x1a2cf0eb00>,
#  'speed': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ed30>,
#  'attain': <gensim.models.keyedvectors.Vocab at 0x1a2cf0e780>,
#  'cpu': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f5c0>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f898>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f048>,
#  'card': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f128>,
#  'adapt': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f438>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x1a2cf0fa90>,
#  'sink': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f518>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ffd0>,
#  'usag': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f7f0>,
#  'per': <gensim.models.keyedvectors.Vocab at 0x1a2cf0fd30>,
#  'floppi': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f6a0>,
#  'disk': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f550>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f390>,
#  'especi': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f978>,
#  'request': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ff98>,
#  'summar': <gensim.models.keyedvectors.Vocab at 0x1a2cf0fdd8>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x1a2cf0fbe0>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f710>,
#  'network': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f8d0>,
#  'knowledg': <gensim.models.keyedvectors.Vocab at 0x1a2cf0ff28>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x1a2cf0fa58>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f208>,
#  'answer': <gensim.models.keyedvectors.Vocab at 0x1a2cf0fcc0>,
#  'twilli': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f0b8>,
#  'ec': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f5f8>,
#  'ecn': <gensim.models.keyedvectors.Vocab at 0x1a2cf0f278>,
#  'purdu': <gensim.models.keyedvectors.Vocab at 0x1a2cf10240>,
#  'thoma': <gensim.models.keyedvectors.Vocab at 0x1a2cf10b00>,
#  'willi': <gensim.models.keyedvectors.Vocab at 0x1a2cf10a90>,
#  'pb': <gensim.models.keyedvectors.Vocab at 0x1a2cf10cc0>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x1a2cf10160>,
#  'comput': <gensim.models.keyedvectors.Vocab at 0x1a2cf10b38>,
#  'distribut': <gensim.models.keyedvectors.Vocab at 0x1a2cf10550>,
#  'usa': <gensim.models.keyedvectors.Vocab at 0x1a2cf10518>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x1a2cf101d0>,
#  'folk': <gensim.models.keyedvectors.Vocab at 0x1a2cf10a20>,
#  'mac': <gensim.models.keyedvectors.Vocab at 0x1a2cf10898>,
#  'plu': <gensim.models.keyedvectors.Vocab at 0x1a2cf10860>,
#  'gave': <gensim.models.keyedvectors.Vocab at 0x1a2cf10748>,
#  'ghost': <gensim.models.keyedvectors.Vocab at 0x1a2cf10588>,
#  'weekend': <gensim.models.keyedvectors.Vocab at 0x1a2cf21048>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x1a2cf21080>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x1a2cf210b8>,
#  'k': <gensim.models.keyedvectors.Vocab at 0x1a2cf210f0>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x1a2cf21128>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x1a2cf21160>,
#  'sooo': <gensim.models.keyedvectors.Vocab at 0x1a2cf21198>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x1a2cf211d0>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x1a2cf21208>,
#  'machin': <gensim.models.keyedvectors.Vocab at 0x1a2cf21240>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x1a2cf21278>,
#  'sooner': <gensim.models.keyedvectors.Vocab at 0x1a2cf212b0>,
#  'intend': <gensim.models.keyedvectors.Vocab at 0x1a2cf212e8>,
#  'pick': <gensim.models.keyedvectors.Vocab at 0x1a2cf21320>,
#  'powerbook': <gensim.models.keyedvectors.Vocab at 0x1a2cf21358>,
#  'mayb': <gensim.models.keyedvectors.Vocab at 0x1a2cf21390>,
#  'bunch': <gensim.models.keyedvectors.Vocab at 0x1a2cf213c8>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x1a2cf21400>,
#  'somebodi': <gensim.models.keyedvectors.Vocab at 0x1a2cf21438>,
#  'anybodi': <gensim.models.keyedvectors.Vocab at 0x1a2cf21470>,
#  'dirt': <gensim.models.keyedvectors.Vocab at 0x1a2cf214a8>,
#  'round': <gensim.models.keyedvectors.Vocab at 0x1a2cf214e0>,
#  'introduct': <gensim.models.keyedvectors.Vocab at 0x1a2cf21518>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x1a2cf21550>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x1a2cf21588>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x1a2cf215c0>,
#  'suppos': <gensim.models.keyedvectors.Vocab at 0x1a2cf215f8>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x1a2cf21630>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x1a2cf21668>,
#  'summer': <gensim.models.keyedvectors.Vocab at 0x1a2cf216a0>,
#  'anymor': <gensim.models.keyedvectors.Vocab at 0x1a2cf216d8>,
#  'sinc': <gensim.models.keyedvectors.Vocab at 0x1a2cf21710>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x1a2cf21748>,
#  'macleak': <gensim.models.keyedvectors.Vocab at 0x1a2cf21780>,
#  'rumor': <gensim.models.keyedvectors.Vocab at 0x1a2cf217b8>,
#  'price': <gensim.models.keyedvectors.Vocab at 0x1a2cf217f0>,
#  'drop': <gensim.models.keyedvectors.Vocab at 0x1a2cf21828>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x1a2cf21860>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x1a2cf21898>,
#  'duo': <gensim.models.keyedvectors.Vocab at 0x1a2cf218d0>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x1a2cf21908>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x1a2cf21940>,
#  'impress': <gensim.models.keyedvectors.Vocab at 0x1a2cf21978>,
#  'display': <gensim.models.keyedvectors.Vocab at 0x1a2cf219b0>,
#  'probabl': <gensim.models.keyedvectors.Vocab at 0x1a2cf219e8>,
#  'swing': <gensim.models.keyedvectors.Vocab at 0x1a2cf21a20>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x1a2cf21a58>,
#  'mb': <gensim.models.keyedvectors.Vocab at 0x1a2cf21a90>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x1a2cf21ac8>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x1a2cf21b00>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x1a2cf21b38>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x1a2cf21b70>,
#  'yea': <gensim.models.keyedvectors.Vocab at 0x1a2cf21ba8>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x1a2cf21be0>,
#  'store': <gensim.models.keyedvectors.Vocab at 0x1a2cf21c18>,
#  'wow': <gensim.models.keyedvectors.Vocab at 0x1a2cf21c50>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x1a2cf21c88>,
#  'solicit': <gensim.models.keyedvectors.Vocab at 0x1a2cf21cc0>,
#  'opinion': <gensim.models.keyedvectors.Vocab at 0x1a2cf21cf8>,
#  'peopl': <gensim.models.keyedvectors.Vocab at 0x1a2cf21d30>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x1a2cf21d68>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x1a2cf21da0>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x1a2cf21dd8>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x1a2cf21e10>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x1a2cf21e48>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x1a2cf21e80>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x1a2cf21eb8>,
#  'activ': <gensim.models.keyedvectors.Vocab at 0x1a2cf21ef0>,
#  'realiz': <gensim.models.keyedvectors.Vocab at 0x1a2cf21f28>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x1a2cf21f60>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x1a2cf21f98>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x1a2cf21fd0>,
#  'breifli': <gensim.models.keyedvectors.Vocab at 0x1a2cf23048>,
#  'figur': <gensim.models.keyedvectors.Vocab at 0x1a2cf23080>,
#  'actual': <gensim.models.keyedvectors.Vocab at 0x1a2cf230b8>,
#  'daili': <gensim.models.keyedvectors.Vocab at 0x1a2cf230f0>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x1a2cf23128>,
#  'prove': <gensim.models.keyedvectors.Vocab at 0x1a2cf23160>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x1a2cf23198>,
#  'hellcat': <gensim.models.keyedvectors.Vocab at 0x1a2cf231d0>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x1a2cf23208>,
#  'advanc': <gensim.models.keyedvectors.Vocab at 0x1a2cf23240>,
#  'email': <gensim.models.keyedvectors.Vocab at 0x1a2cf23278>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x1a2cf232b0>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x1a2cf232e8>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x1a2cf23320>,
#  'premium': <gensim.models.keyedvectors.Vocab at 0x1a2cf23358>,
#  'corner': <gensim.models.keyedvectors.Vocab at 0x1a2cf23390>,
#  'tom': <gensim.models.keyedvectors.Vocab at 0x1a2cf233c8>,
#  'electr': <gensim.models.keyedvectors.Vocab at 0x1a2cf23400>,
#  'convict': <gensim.models.keyedvectors.Vocab at 0x1a2cf23438>,
#  'danger': <gensim.models.keyedvectors.Vocab at 0x1a2cf23470>,
#  'enemi': <gensim.models.keyedvectors.Vocab at 0x1a2cf234a8>,
#  'truth': <gensim.models.keyedvectors.Vocab at 0x1a2cf234e0>,
#  'lie': <gensim.models.keyedvectors.Vocab at 0x1a2cf23518>,
#  'f': <gensim.models.keyedvectors.Vocab at 0x1a2cf23550>,
#  'w': <gensim.models.keyedvectors.Vocab at 0x1a2cf23588>,
#  'nietzsch': <gensim.models.keyedvectors.Vocab at 0x1a2cf235c0>,
#  'jgreen': <gensim.models.keyedvectors.Vocab at 0x1a2cf235f8>,
#  'amber': <gensim.models.keyedvectors.Vocab at 0x1a2cf23630>,
#  'joe': <gensim.models.keyedvectors.Vocab at 0x1a2cf23668>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x1a2cf236a0>,
#  'weitek': <gensim.models.keyedvectors.Vocab at 0x1a2cf236d8>,
#  'p': <gensim.models.keyedvectors.Vocab at 0x1a2cf23710>,
#  'harri': <gensim.models.keyedvectors.Vocab at 0x1a2cf23748>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x1a2cf23780>,
#  'divis': <gensim.models.keyedvectors.Vocab at 0x1a2cf237b8>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x1a2cf237f0>,
#  'ssd': <gensim.models.keyedvectors.Vocab at 0x1a2cf23828>,
#  'csd': <gensim.models.keyedvectors.Vocab at 0x1a2cf23860>,
#  'com': <gensim.models.keyedvectors.Vocab at 0x1a2cf23898>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x1a2cf238d0>,
#  'newsread': <gensim.models.keyedvectors.Vocab at 0x1a2cf23908>,
#  'tin': <gensim.models.keyedvectors.Vocab at 0x1a2cf23940>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x1a2cf23978>,
#  'pl': <gensim.models.keyedvectors.Vocab at 0x1a2cf239b0>,
#  'robert': <gensim.models.keyedvectors.Vocab at 0x1a2cf239e8>,
#  'j': <gensim.models.keyedvectors.Vocab at 0x1a2cf23a20>,
#  'kyanko': <gensim.models.keyedvectors.Vocab at 0x1a2cf23a58>,
#  'rob': <gensim.models.keyedvectors.Vocab at 0x1a2cf23a90>,
#  'rjck': <gensim.models.keyedvectors.Vocab at 0x1a2cf23ac8>,
#  'uucp': <gensim.models.keyedvectors.Vocab at 0x1a2cf23b00>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x1a2cf23b38>,
#  'abraxi': <gensim.models.keyedvectors.Vocab at 0x1a2cf23b70>,
#  'iastat': <gensim.models.keyedvectors.Vocab at 0x1a2cf23ba8>,
#  'write': <gensim.models.keyedvectors.Vocab at 0x1a2cf23be0>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x1a2cf23c18>,
#  'graphic': <gensim.models.keyedvectors.Vocab at 0x1a2cf23c50>,
#  'chip': <gensim.models.keyedvectors.Vocab at 0x1a2cf23c88>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x1a2cf23cc0>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x1a2cf23cf8>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x1a2cf23d30>,
#  'stuff': <gensim.models.keyedvectors.Vocab at 0x1a2cf23d68>,
#  'goe': <gensim.models.keyedvectors.Vocab at 0x1a2cf23da0>,
#  'pretti': <gensim.models.keyedvectors.Vocab at 0x1a2cf23dd8>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x1a2cf23e10>,
#  'quadrilater': <gensim.models.keyedvectors.Vocab at 0x1a2cf23e48>,
#  'fill': <gensim.models.keyedvectors.Vocab at 0x1a2cf23e80>,
#  'command': <gensim.models.keyedvectors.Vocab at 0x1a2cf23eb8>,
#  'requir': <gensim.models.keyedvectors.Vocab at 0x1a2cf23ef0>,
#  'four': <gensim.models.keyedvectors.Vocab at 0x1a2cf23f28>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x1a2cf23f60>,
#  'address': <gensim.models.keyedvectors.Vocab at 0x1a2cf23f98>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x1a2cf23fd0>,
#  'inform': <gensim.models.keyedvectors.Vocab at 0x1a2cf28048>,
#  'corpor': <gensim.models.keyedvectors.Vocab at 0x1a2cf28080>,
#  'scare': <gensim.models.keyedvectors.Vocab at 0x1a2cf280b8>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x1a2cf280f0>,
#  'sens': <gensim.models.keyedvectors.Vocab at 0x1a2cf28128>,
#  'humor': <gensim.models.keyedvectors.Vocab at 0x1a2cf28160>,
#  'jonathan': <gensim.models.keyedvectors.Vocab at 0x1a2cf28198>,
#  'winter': <gensim.models.keyedvectors.Vocab at 0x1a2cf281d0>,
#  'jcm': <gensim.models.keyedvectors.Vocab at 0x1a2cf28208>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x1a2cf28240>,
#  'cfa': <gensim.models.keyedvectors.Vocab at 0x1a2cf28278>,
#  'harvard': <gensim.models.keyedvectors.Vocab at 0x1a2cf282b0>,
#  'mcdowel': <gensim.models.keyedvectors.Vocab at 0x1a2cf282e8>,
#  'shuttl': <gensim.models.keyedvectors.Vocab at 0x1a2cf28320>,
#  'launch': <gensim.models.keyedvectors.Vocab at 0x1a2cf28358>,
#  'smithsonian': <gensim.models.keyedvectors.Vocab at 0x1a2cf28390>,
#  'astrophys': <gensim.models.keyedvectors.Vocab at 0x1a2cf283c8>,
#  'observatori': <gensim.models.keyedvectors.Vocab at 0x1a2cf28400>,
#  'cambridg': <gensim.models.keyedvectors.Vocab at 0x1a2cf28438>,
#  'sci': <gensim.models.keyedvectors.Vocab at 0x1a2cf28470>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x1a2cf284a8>,
#  'std': <gensim.models.keyedvectors.Vocab at 0x1a2cf284e0>,
#  'tombak': <gensim.models.keyedvectors.Vocab at 0x1a2cf28518>,
#  'baker': <gensim.models.keyedvectors.Vocab at 0x1a2cf28550>,
#  'jlwx': <gensim.models.keyedvectors.Vocab at 0x1a2cf28588>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x1a2cf285c0>,
#  'cs': <gensim.models.keyedvectors.Vocab at 0x1a2cf285f8>,
#  'cmu': <gensim.models.keyedvectors.Vocab at 0x1a2cf28630>,
#  'etrat': <gensim.models.keyedvectors.Vocab at 0x1a2cf28668>,
#  'ttac': <gensim.models.keyedvectors.Vocab at 0x1a2cf286a0>,
#  'ttu': <gensim.models.keyedvectors.Vocab at 0x1a2cf286d8>,
#  'pack': <gensim.models.keyedvectors.Vocab at 0x1a2cf28710>,
#  'rat': <gensim.models.keyedvectors.Vocab at 0x1a2cf28748>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x1a2cf28780>,
#  'caution': <gensim.models.keyedvectors.Vocab at 0x1a2cf287b8>,
#  'warn': <gensim.models.keyedvectors.Vocab at 0x1a2cf287f0>,
#  'memori': <gensim.models.keyedvectors.Vocab at 0x1a2cf28828>,
#  'verifi': <gensim.models.keyedvectors.Vocab at 0x1a2cf28860>,
#  'unexpect': <gensim.models.keyedvectors.Vocab at 0x1a2cf28898>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x1a2cf288d0>,
#  'sorri': <gensim.models.keyedvectors.Vocab at 0x1a2cf28908>,
#  'dumb': <gensim.models.keyedvectors.Vocab at 0x1a2cf28940>,
#  'pariti': <gensim.models.keyedvectors.Vocab at 0x1a2cf28978>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x1a2cf289b0>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x1a2cf289e8>,
#  'condit': <gensim.models.keyedvectors.Vocab at 0x1a2cf28a20>,
#  'waiver': <gensim.models.keyedvectors.Vocab at 0x1a2cf28a58>,
#  'ye': <gensim.models.keyedvectors.Vocab at 0x1a2cf28a90>,
#  'alreadi': <gensim.models.keyedvectors.Vocab at 0x1a2cf28ac8>,
#  'knew': <gensim.models.keyedvectors.Vocab at 0x1a2cf28b00>,
#  'curiou': <gensim.models.keyedvectors.Vocab at 0x1a2cf28b38>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x1a2cf28b70>,
#  'quot': <gensim.models.keyedvectors.Vocab at 0x1a2cf28ba8>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x1a2cf28be0>,
#  'basic': <gensim.models.keyedvectors.Vocab at 0x1a2cf28c18>,
#  'bug': <gensim.models.keyedvectors.Vocab at 0x1a2cf28c50>,
#  'softwar': <gensim.models.keyedvectors.Vocab at 0x1a2cf28c88>,
#  'check': <gensim.models.keyedvectors.Vocab at 0x1a2cf28cc0>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x1a2cf28cf8>,
#  'valu': <gensim.models.keyedvectors.Vocab at 0x1a2cf28d30>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x1a2cf28d68>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x1a2cf28da0>,
#  'till': <gensim.models.keyedvectors.Vocab at 0x1a2cf28dd8>,
#  'suchlik': <gensim.models.keyedvectors.Vocab at 0x1a2cf28e10>,
#  'fix': <gensim.models.keyedvectors.Vocab at 0x1a2cf28e48>,
#  'code': <gensim.models.keyedvectors.Vocab at 0x1a2cf28e80>,
#  'possibl': <gensim.models.keyedvectors.Vocab at 0x1a2cf28eb8>,
#  'introduc': <gensim.models.keyedvectors.Vocab at 0x1a2cf28ef0>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x1a2cf28f28>,
#  'crew': <gensim.models.keyedvectors.Vocab at 0x1a2cf28f60>,
#  'ok': <gensim.models.keyedvectors.Vocab at 0x1a2cf28f98>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x1a2cf28fd0>,
#  'liftoff': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b048>,
#  'ignor': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b080>,
#  'dfo': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b0b8>,
#  'vttoulu': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b0f0>,
#  'tko': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b128>,
#  'vtt': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b160>,
#  'fi': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b198>,
#  'foxvog': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b1d0>,
#  'dougla': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b208>,
#  'reword': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b240>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b278>,
#  'amend': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b2b0>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b2e8>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b320>,
#  'eu': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b358>,
#  'transfer': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b390>,
#  'stratu': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b3c8>,
#  'cdt': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b400>,
#  'sw': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b438>,
#  'tavar': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b470>,
#  'apr': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b4a8>,
#  'ousrvr': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b4e0>,
#  'oulu': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b518>,
#  'qv': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b550>,
#  'v': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b588>,
#  'gi': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b5c0>,
#  'ulowel': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b5f8>,
#  'jrutledg': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b630>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b668>,
#  'lawrenc': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b6a0>,
#  'rutledg': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b6d8>,
#  'massiv': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b710>,
#  'destruct': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b748>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b780>,
#  'mani': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b7b8>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b7f0>,
#  'weapon': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b828>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b860>,
#  'accident': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b898>,
#  'crimial': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b8d0>,
#  'mass': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b908>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b940>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b978>,
#  'govern': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b9b0>,
#  'individu': <gensim.models.keyedvectors.Vocab at 0x1a2cf2b9e8>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x1a2cf2ba20>,
#  'result': <gensim.models.keyedvectors.Vocab at 0x1a2cf2ba58>,
#  'needless': <gensim.models.keyedvectors.Vocab at 0x1a2cf2ba90>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bac8>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bb00>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bb38>,
#  'bear': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bb70>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bba8>,
#  'exist': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bbe0>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bc18>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bc50>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bc88>,
#  'disagre': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bcc0>,
#  'everi': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bcf8>,
#  'count': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bd30>,
#  'believ': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bd68>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bda0>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bdd8>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x1a2cf2be10>,
#  'neighbor': <gensim.models.keyedvectors.Vocab at 0x1a2cf2be48>,
#  'nuclear': <gensim.models.keyedvectors.Vocab at 0x1a2cf2be80>,
#  'biolog': <gensim.models.keyedvectors.Vocab at 0x1a2cf2beb8>,
#  'nerv': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bef0>,
#  'ga': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bf28>,
#  'properti': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bf60>,
#  'cannot': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bf98>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x1a2cf2bfd0>,
#  'agre': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f048>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f080>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f0b8>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f0f0>,
#  'blank': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f128>,
#  'cours': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f160>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f198>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f1d0>,
#  'rigidli': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f208>,
#  'defin': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f240>,
#  'bill': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f278>,
#  'doug': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f2b0>,
#  'cbw': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f2e8>,
#  'nuke': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f320>,
#  'sarah': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f358>,
#  'bradi': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f390>,
#  'street': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f3c8>,
#  'sweeper': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f400>,
#  'shotgun': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f438>,
#  'semi': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f470>,
#  'automat': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f4a8>,
#  'sk': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f4e0>,
#  'rifl': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f518>,
#  'doubt': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f550>,
#  'allegedli': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f588>,
#  'immedi': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f5c0>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f5f8>,
#  'thousand': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f630>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f668>,
#  'handgun': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f6a0>,
#  'easili': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f6d8>,
#  'reduc': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f710>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f748>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f780>,
#  'restrict': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f7b8>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f7f0>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f828>,
#  'argument': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f860>,
#  'commonli': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f898>,
#  'understood': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f8d0>,
#  'switch': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f908>,
#  'topic': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f940>,
#  'evid': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f978>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f9b0>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x1a2cf2f9e8>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fa20>,
#  'analysi': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fa58>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fa90>,
#  'consid': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fac8>,
#  'anoth': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fb00>,
#  'rocket': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fb38>,
#  'speak': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fb70>,
#  'compani': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fba8>,
#  'vo': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fbe0>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fc18>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fc50>,
#  'investor': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fc88>,
#  'packet': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fcc0>,
#  'bmdelan': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fcf8>,
#  'quad': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fd30>,
#  'uchicago': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fd68>,
#  'brian': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fda0>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fdd8>,
#  'delaney': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fe10>,
#  'brain': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fe48>,
#  'tumor': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fe80>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x1a2cf2feb8>,
#  'repli': <gensim.models.keyedvectors.Vocab at 0x1a2cf2fef0>,
#  'midway': <gensim.models.keyedvectors.Vocab at 0x1a2cf2ff28>,
#  'chicago': <gensim.models.keyedvectors.Vocab at 0x1a2cf2ff60>,
#  'respond': <gensim.models.keyedvectors.Vocab at 0x1a2cf2ff98>,
#  'directli': <gensim.models.keyedvectors.Vocab at 0x1a2cf2ffd0>,
#  'bounc': <gensim.models.keyedvectors.Vocab at 0x1a2cf31048>,
#  'prob': <gensim.models.keyedvectors.Vocab at 0x1a2cf31080>,
#  'sean': <gensim.models.keyedvectors.Vocab at 0x1a2cf310b8>,
#  'debra': <gensim.models.keyedvectors.Vocab at 0x1a2cf310f0>,
#  'sharon': <gensim.models.keyedvectors.Vocab at 0x1a2cf31128>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x1a2cf31160>,
#  'publicli': <gensim.models.keyedvectors.Vocab at 0x1a2cf31198>,
#  'everyon': <gensim.models.keyedvectors.Vocab at 0x1a2cf311d0>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x1a2cf31208>,
#  'glad': <gensim.models.keyedvectors.Vocab at 0x1a2cf31240>,
#  'rn': <gensim.models.keyedvectors.Vocab at 0x1a2cf31278>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x1a2cf312b0>,
#  'rm': <gensim.models.keyedvectors.Vocab at 0x1a2cf312e8>,
#  'tri': <gensim.models.keyedvectors.Vocab at 0x1a2cf31320>,
#  'delet': <gensim.models.keyedvectors.Vocab at 0x1a2cf31358>,
#  'file': <gensim.models.keyedvectors.Vocab at 0x1a2cf31390>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x1a2cf313c8>,
#  'septemb': <gensim.models.keyedvectors.Vocab at 0x1a2cf31400>,
#  'hmmm': <gensim.models.keyedvectors.Vocab at 0x1a2cf31438>,
#  'bgrubb': <gensim.models.keyedvectors.Vocab at 0x1a2cf31470>,
#  'dant': <gensim.models.keyedvectors.Vocab at 0x1a2cf314a8>,
#  'nmsu': <gensim.models.keyedvectors.Vocab at 0x1a2cf314e0>,
#  'grubb': <gensim.models.keyedvectors.Vocab at 0x1a2cf31518>,
#  'ide': <gensim.models.keyedvectors.Vocab at 0x1a2cf31550>,
#  'vs': <gensim.models.keyedvectors.Vocab at 0x1a2cf31588>,
#  'scsi': <gensim.models.keyedvectors.Vocab at 0x1a2cf315c0>,
#  'mexico': <gensim.models.keyedvectors.Vocab at 0x1a2cf315f8>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x1a2cf31630>,
#  'cruce': <gensim.models.keyedvectors.Vocab at 0x1a2cf31668>,
#  'nm': <gensim.models.keyedvectors.Vocab at 0x1a2cf316a0>,
#  'dxb': <gensim.models.keyedvectors.Vocab at 0x1a2cf316d8>,
#  'psuvm': <gensim.models.keyedvectors.Vocab at 0x1a2cf31710>,
#  'psu': <gensim.models.keyedvectors.Vocab at 0x1a2cf31748>,
#  'qlbrlinn': <gensim.models.keyedvectors.Vocab at 0x1a2cf31780>,
#  'rk': <gensim.models.keyedvectors.Vocab at 0x1a2cf317b8>,
#  'dn': <gensim.models.keyedvectors.Vocab at 0x1a2cf317f0>,
#  'pc': <gensim.models.keyedvectors.Vocab at 0x1a2cf31828>,
#  'magazin': <gensim.models.keyedvectors.Vocab at 0x1a2cf31860>,
#  'april': <gensim.models.keyedvectors.Vocab at 0x1a2cf31898>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x1a2cf318d0>,
#  'twice': <gensim.models.keyedvectors.Vocab at 0x1a2cf31908>,
#  'fasst': <gensim.models.keyedvectors.Vocab at 0x1a2cf31940>,
#  'esdi': <gensim.models.keyedvectors.Vocab at 0x1a2cf31978>,
#  'faster': <gensim.models.keyedvectors.Vocab at 0x1a2cf319b0>,
#  'devic': <gensim.models.keyedvectors.Vocab at 0x1a2cf319e8>,
#  'accept': <gensim.models.keyedvectors.Vocab at 0x1a2cf31a20>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x1a2cf31a58>,
#  'stall': <gensim.models.keyedvectors.Vocab at 0x1a2cf31a90>,
#  'incompat': <gensim.models.keyedvectors.Vocab at 0x1a2cf31ac8>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x1a2cf31b00>,
#  'instal': <gensim.models.keyedvectors.Vocab at 0x1a2cf31b38>,
#  'headach': <gensim.models.keyedvectors.Vocab at 0x1a2cf31b70>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x1a2cf31ba8>,
#  'writer': <gensim.models.keyedvectors.Vocab at 0x1a2cf31be0>,
#  'stupid': <gensim.models.keyedvectors.Vocab at 0x1a2cf31c18>,
#  'statement': <gensim.models.keyedvectors.Vocab at 0x1a2cf31c50>,
#  'list': <gensim.models.keyedvectors.Vocab at 0x1a2cf31c88>,
#  'rang': <gensim.models.keyedvectors.Vocab at 0x1a2cf31cc0>,
#  'convinc': <gensim.models.keyedvectors.Vocab at 0x1a2cf31cf8>,
#  'absurd': <gensim.models.keyedvectors.Vocab at 0x1a2cf31d30>,
#  'ii': <gensim.models.keyedvectors.Vocab at 0x1a2cf31d68>,
#  'alway': <gensim.models.keyedvectors.Vocab at 0x1a2cf31da0>,
#  'standard': <gensim.models.keyedvectors.Vocab at 0x1a2cf31dd8>,
#  'inde': <gensim.models.keyedvectors.Vocab at 0x1a2cf31e10>,
#  'burst': <gensim.models.keyedvectors.Vocab at 0x1a2cf31e48>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x1a2cf31e80>,
#  'increas': <gensim.models.keyedvectors.Vocab at 0x1a2cf31eb8>,
#  'quadra': <gensim.models.keyedvectors.Vocab at 0x1a2cf31ef0>,
#  'mode': <gensim.models.keyedvectors.Vocab at 0x1a2cf31f28>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x1a2cf31f60>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x1a2cf31f98>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x1a2cf31fd0>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x1a2cf36048>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x1a2cf36080>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x1a2cf360b8>,
#  'newsgroup': <gensim.models.keyedvectors.Vocab at 0x1a2cf360f0>,
#  'ibm': <gensim.models.keyedvectors.Vocab at 0x1a2cf36128>,
#  'sheet': <gensim.models.keyedvectors.Vocab at 0x1a2cf36160>,
#  'avail': <gensim.models.keyedvectors.Vocab at 0x1a2cf36198>,
#  'ftp': <gensim.models.keyedvectors.Vocab at 0x1a2cf361d0>,
#  'sumex': <gensim.models.keyedvectors.Vocab at 0x1a2cf36208>,
#  'aim': <gensim.models.keyedvectors.Vocab at 0x1a2cf36240>,
#  'stanford': <gensim.models.keyedvectors.Vocab at 0x1a2cf36278>,
#  'compar': <gensim.models.keyedvectors.Vocab at 0x1a2cf362b0>,
#  'txt': <gensim.models.keyedvectors.Vocab at 0x1a2cf362e8>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x1a2cf36320>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x1a2cf36358>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x1a2cf36390>,
#  'inconsi': <gensim.models.keyedvectors.Vocab at 0x1a2cf363c8>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x1a2cf36400>,
#  'document': <gensim.models.keyedvectors.Vocab at 0x1a2cf36438>,
#  'appl': <gensim.models.keyedvectors.Vocab at 0x1a2cf36470>,
#  'salesperson': <gensim.models.keyedvectors.Vocab at 0x1a2cf364a8>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x1a2cf364e0>,
#  'maximum': <gensim.models.keyedvectors.Vocab at 0x1a2cf36518>,
#  'synchron': <gensim.models.keyedvectors.Vocab at 0x1a2cf36550>,
#  'ansynchron': <gensim.models.keyedvectors.Vocab at 0x1a2cf36588>,
#  'slower': <gensim.models.keyedvectors.Vocab at 0x1a2cf365c0>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x1a2cf365f8>,
#  'interfac': <gensim.models.keyedvectors.Vocab at 0x1a2cf36630>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x1a2cf36668>,
#  'driven': <gensim.models.keyedvectors.Vocab at 0x1a2cf366a0>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x1a2cf366d8>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x1a2cf36710>,
#  'slam': <gensim.models.keyedvectors.Vocab at 0x1a2cf36748>,
#  'refer': <gensim.models.keyedvectors.Vocab at 0x1a2cf36780>,
#  'digit': <gensim.models.keyedvectors.Vocab at 0x1a2cf367b8>,
#  'review': <gensim.models.keyedvectors.Vocab at 0x1a2cf367f0>,
#  'oct': <gensim.models.keyedvectors.Vocab at 0x1a2cf36828>,
#  'holm': <gensim.models.keyedvectors.Vocab at 0x1a2cf36860>,
#  'iscsvax': <gensim.models.keyedvectors.Vocab at 0x1a2cf36898>,
#  'uni': <gensim.models.keyedvectors.Vocab at 0x1a2cf368d0>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x1a2cf36908>,
#  'icon': <gensim.models.keyedvectors.Vocab at 0x1a2cf36940>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x1a2cf36978>,
#  'iowa': <gensim.models.keyedvectors.Vocab at 0x1a2cf369b0>,
#  'download': <gensim.models.keyedvectors.Vocab at 0x1a2cf369e8>,
#  'sever': <gensim.models.keyedvectors.Vocab at 0x1a2cf36a20>,
#  'bmp': <gensim.models.keyedvectors.Vocab at 0x1a2cf36a58>,
#  'chang': <gensim.models.keyedvectors.Vocab at 0x1a2cf36a90>,
#  'wallpap': <gensim.models.keyedvectors.Vocab at 0x1a2cf36ac8>,
#  'appreci': <gensim.models.keyedvectors.Vocab at 0x1a2cf36b00>,
#  'thanx': <gensim.models.keyedvectors.Vocab at 0x1a2cf36b38>,
#  'ps': <gensim.models.keyedvectors.Vocab at 0x1a2cf36b70>,
#  'kerr': <gensim.models.keyedvectors.Vocab at 0x1a2cf36ba8>,
#  'ux': <gensim.models.keyedvectors.Vocab at 0x1a2cf36be0>,
#  'cso': <gensim.models.keyedvectors.Vocab at 0x1a2cf36c18>,
#  'uiuc': <gensim.models.keyedvectors.Vocab at 0x1a2cf36c50>,
#  'stan': <gensim.models.keyedvectors.Vocab at 0x1a2cf36c88>,
#  'sigma': <gensim.models.keyedvectors.Vocab at 0x1a2cf36cc0>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x1a2cf36cf8>,
#  'doubl': <gensim.models.keyedvectors.Vocab at 0x1a2cf36d30>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x1a2cf36d68>,
#  'illinoi': <gensim.models.keyedvectors.Vocab at 0x1a2cf36da0>,
#  'urbana': <gensim.models.keyedvectors.Vocab at 0x1a2cf36dd8>,
#  'jap': <gensim.models.keyedvectors.Vocab at 0x1a2cf36e10>,
#  'po': <gensim.models.keyedvectors.Vocab at 0x1a2cf36e48>,
#  'cwru': <gensim.models.keyedvectors.Vocab at 0x1a2cf36e80>,
#  'joseph': <gensim.models.keyedvectors.Vocab at 0x1a2cf36eb8>,
#  'pellettier': <gensim.models.keyedvectors.Vocab at 0x1a2cf36ef0>,
#  'board': <gensim.models.keyedvectors.Vocab at 0x1a2cf36f28>,
#  'hardwar': <gensim.models.keyedvectors.Vocab at 0x1a2cf36f60>,
#  'compress': <gensim.models.keyedvectors.Vocab at 0x1a2cf36f98>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x1a2cf36fd0>,
#  'autodoubl': <gensim.models.keyedvectors.Vocab at 0x1a2cf39048>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x1a2cf39080>,
#  'diskdoubl': <gensim.models.keyedvectors.Vocab at 0x1a2cf390b8>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x1a2cf390f0>,
#  'licens': <gensim.models.keyedvectors.Vocab at 0x1a2cf39128>,
#  'stac': <gensim.models.keyedvectors.Vocab at 0x1a2cf39160>,
#  'technolog': <gensim.models.keyedvectors.Vocab at 0x1a2cf39198>,
#  'owner': <gensim.models.keyedvectors.Vocab at 0x1a2cf391d0>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x1a2cf39208>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x1a2cf39240>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x1a2cf39278>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x1a2cf392b0>,
#  'someth': <gensim.models.keyedvectors.Vocab at 0x1a2cf392e8>,
#  'els': <gensim.models.keyedvectors.Vocab at 0x1a2cf39320>,
#  'howev': <gensim.models.keyedvectors.Vocab at 0x1a2cf39358>,
#  'decompress': <gensim.models.keyedvectors.Vocab at 0x1a2cf39390>,
#  'troubl': <gensim.models.keyedvectors.Vocab at 0x1a2cf393c8>,
#  'recompress': <gensim.models.keyedvectors.Vocab at 0x1a2cf39400>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x1a2cf39438>,
#  'usual': <gensim.models.keyedvectors.Vocab at 0x1a2cf39470>,
#  'reappear': <gensim.models.keyedvectors.Vocab at 0x1a2cf394a8>,
#  'mention': <gensim.models.keyedvectors.Vocab at 0x1a2cf394e0>,
#  'freewar': <gensim.models.keyedvectors.Vocab at 0x1a2cf39518>,
#  'expans': <gensim.models.keyedvectors.Vocab at 0x1a2cf39550>,
#  'util': <gensim.models.keyedvectors.Vocab at 0x1a2cf39588>,
#  'dd': <gensim.models.keyedvectors.Vocab at 0x1a2cf395c0>,
#  'expand': <gensim.models.keyedvectors.Vocab at 0x1a2cf395f8>,
#  'unless': <gensim.models.keyedvectors.Vocab at 0x1a2cf39630>,
#  'unlik': <gensim.models.keyedvectors.Vocab at 0x1a2cf39668>,
#  'hole': <gensim.models.keyedvectors.Vocab at 0x1a2cf396a0>,
#  'relat': <gensim.models.keyedvectors.Vocab at 0x1a2cf396d8>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x1a2cf39710>,
#  'reluct': <gensim.models.keyedvectors.Vocab at 0x1a2cf39748>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x1a2cf39780>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x1a2cf397b8>,
#  'competit': <gensim.models.keyedvectors.Vocab at 0x1a2cf397f0>,
#  'commun': <gensim.models.keyedvectors.Vocab at 0x1a2cf39828>,
#  'servic': <gensim.models.keyedvectors.Vocab at 0x1a2cf39860>,
#  'offic': <gensim.models.keyedvectors.Vocab at 0x1a2cf39898>,
#  'stankerr': <gensim.models.keyedvectors.Vocab at 0x1a2cf398d0>,
#  'irwin': <gensim.models.keyedvectors.Vocab at 0x1a2cf39908>,
#  'cmptrc': <gensim.models.keyedvectors.Vocab at 0x1a2cf39940>,
#  'lonestar': <gensim.models.keyedvectors.Vocab at 0x1a2cf39978>,
#  'org': <gensim.models.keyedvectors.Vocab at 0x1a2cf399b0>,
#  'arnstein': <gensim.models.keyedvectors.Vocab at 0x1a2cf399e8>,
#  'recommend': <gensim.models.keyedvectors.Vocab at 0x1a2cf39a20>,
#  'duc': <gensim.models.keyedvectors.Vocab at 0x1a2cf39a58>,
#  'expir': <gensim.models.keyedvectors.Vocab at 0x1a2cf39a90>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x1a2cf39ac8>,
#  'gmt': <gensim.models.keyedvectors.Vocab at 0x1a2cf39b00>,
#  'computrac': <gensim.models.keyedvectors.Vocab at 0x1a2cf39b38>,
#  'inc': <gensim.models.keyedvectors.Vocab at 0x1a2cf39b70>,
#  'richardson': <gensim.models.keyedvectors.Vocab at 0x1a2cf39ba8>,
#  'tx': <gensim.models.keyedvectors.Vocab at 0x1a2cf39be0>,
#  'ducati': <gensim.models.keyedvectors.Vocab at 0x1a2cf39c18>,
#  'gt': <gensim.models.keyedvectors.Vocab at 0x1a2cf39c50>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x1a2cf39c88>,
#  'paint': <gensim.models.keyedvectors.Vocab at 0x1a2cf39cc0>,
#  'bronz': <gensim.models.keyedvectors.Vocab at 0x1a2cf39cf8>,
#  'brown': <gensim.models.keyedvectors.Vocab at 0x1a2cf39d30>,
#  'orang': <gensim.models.keyedvectors.Vocab at 0x1a2cf39d68>,
#  'fade': <gensim.models.keyedvectors.Vocab at 0x1a2cf39da0>,
#  'leak': <gensim.models.keyedvectors.Vocab at 0x1a2cf39dd8>,
#  'oil': <gensim.models.keyedvectors.Vocab at 0x1a2cf39e10>,
#  'pop': <gensim.models.keyedvectors.Vocab at 0x1a2cf39e48>,
#  'st': <gensim.models.keyedvectors.Vocab at 0x1a2cf39e80>,
#  'accel': <gensim.models.keyedvectors.Vocab at 0x1a2cf39eb8>,
#  'shop': <gensim.models.keyedvectors.Vocab at 0x1a2cf39ef0>,
#  'tran': <gensim.models.keyedvectors.Vocab at 0x1a2cf39f28>,
#  'sold': <gensim.models.keyedvectors.Vocab at 0x1a2cf39f60>,
#  'bike': <gensim.models.keyedvectors.Vocab at 0x1a2cf39f98>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x1a2cf39fd0>,
#  'stabl': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c048>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c080>,
#  'beemer': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c0b8>,
#  'axi': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c0f0>,
#  'motor': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c128>,
#  'tuba': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c160>,
#  'honk': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c198>,
#  'therefor': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c1d0>,
#  'dod': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c208>,
#  'david': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c240>,
#  'terminu': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c278>,
#  'ericsson': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c2b0>,
#  'se': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c2e8>,
#  'bold': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c320>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c358>,
#  'moral': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c390>,
#  'camtec': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c3c8>,
#  'electron': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c400>,
#  'leicest': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c438>,
#  'england': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c470>,
#  'bangkok': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c4a8>,
#  'freenet': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c4e0>,
#  'carleton': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c518>,
#  'ca': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c550>,
#  'ad': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c588>,
#  'jame': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c5c0>,
#  'owen': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c5f8>,
#  'previou': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c630>,
#  'rude': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c668>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c6a0>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c6d8>,
#  'differ': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c710>,
#  'stick': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c748>,
#  'intent': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c780>,
#  'explain': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c7b8>,
#  'jung': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c7f0>,
#  'god': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c828>,
#  'overlook': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c860>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c898>,
#  'unknow': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c8d0>,
#  'yep': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c908>,
#  'jew': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c940>,
#  'jewish': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c978>,
#  'coven': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c9b0>,
#  'yhwh': <gensim.models.keyedvectors.Vocab at 0x1a2cf3c9e8>,
#  'patriarch': <gensim.models.keyedvectors.Vocab at 0x1a2cf3ca20>,
#  'abraham': <gensim.models.keyedvectors.Vocab at 0x1a2cf3ca58>,
#  'mose': <gensim.models.keyedvectors.Vocab at 0x1a2cf3ca90>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cac8>,
#  'establish': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cb00>,
#  'mankind': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cb38>,
#  'decid': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cb70>,
#  'boundari': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cba8>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cbe0>,
#  'sadduce': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cc18>,
#  'torah': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cc50>,
#  'wherea': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cc88>,
#  'pharise': <gensim.models.keyedvectors.Vocab at 0x1a2cf3ccc0>,
#  'ancestor': <gensim.models.keyedvectors.Vocab at 0x1a2cf3ccf8>,
#  'judaism': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cd30>,
#  'interpret': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cd68>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cda0>,
#  'nuanc': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cdd8>,
#  'talmud': <gensim.models.keyedvectors.Vocab at 0x1a2cf3ce10>,
#  'essenc': <gensim.models.keyedvectors.Vocab at 0x1a2cf3ce48>,
#  'biblic': <gensim.models.keyedvectors.Vocab at 0x1a2cf3ce80>,
#  'christian': <gensim.models.keyedvectors.Vocab at 0x1a2cf3ceb8>,
#  'necessarili': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cef0>,
#  'indic': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cf28>,
#  'anyth': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cf60>,
#  'outsid': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cf98>,
#  'relationship': <gensim.models.keyedvectors.Vocab at 0x1a2cf3cfd0>,
#  'specul': <gensim.models.keyedvectors.Vocab at 0x1a2cf41048>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x1a2cf41080>,
#  'creat': <gensim.models.keyedvectors.Vocab at 0x1a2cf410b8>,
#  'imag': <gensim.models.keyedvectors.Vocab at 0x1a2cf410f0>,
#  'commit': <gensim.models.keyedvectors.Vocab at 0x1a2cf41128>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x1a2cf41160>,
#  'christ': <gensim.models.keyedvectors.Vocab at 0x1a2cf41198>,
#  'exampl': <gensim.models.keyedvectors.Vocab at 0x1a2cf411d0>,
#  'press': <gensim.models.keyedvectors.Vocab at 0x1a2cf41208>,
#  'argu': <gensim.models.keyedvectors.Vocab at 0x1a2cf41240>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x1a2cf41278>,
#  'conclus': <gensim.models.keyedvectors.Vocab at 0x1a2cf412b0>,
#  'upset': <gensim.models.keyedvectors.Vocab at 0x1a2cf412e8>,
#  'cart': <gensim.models.keyedvectors.Vocab at 0x1a2cf41320>,
#  'script': <gensim.models.keyedvectors.Vocab at 0x1a2cf41358>,
#  'shaki': <gensim.models.keyedvectors.Vocab at 0x1a2cf41390>,
#  'foundat': <gensim.models.keyedvectors.Vocab at 0x1a2cf413c8>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x1a2cf41400>,
#  'metaphor': <gensim.models.keyedvectors.Vocab at 0x1a2cf41438>,
#  'littl': <gensim.models.keyedvectors.Vocab at 0x1a2cf41470>,
#  'jesu': <gensim.models.keyedvectors.Vocab at 0x1a2cf414a8>,
#  'record': <gensim.models.keyedvectors.Vocab at 0x1a2cf414e0>,
#  'utter': <gensim.models.keyedvectors.Vocab at 0x1a2cf41518>,
#  'narr': <gensim.models.keyedvectors.Vocab at 0x1a2cf41550>,
#  'historian': <gensim.models.keyedvectors.Vocab at 0x1a2cf41588>,
#  'revel': <gensim.models.keyedvectors.Vocab at 0x1a2cf415c0>,
#  'asid': <gensim.models.keyedvectors.Vocab at 0x1a2cf415f8>,
#  'wors': <gensim.models.keyedvectors.Vocab at 0x1a2cf41630>,
#  'attempt': <gensim.models.keyedvectors.Vocab at 0x1a2cf41668>,
#  'debunk': <gensim.models.keyedvectors.Vocab at 0x1a2cf416a0>,
#  'initi': <gensim.models.keyedvectors.Vocab at 0x1a2cf416d8>,
#  'bibl': <gensim.models.keyedvectors.Vocab at 0x1a2cf41710>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x1a2cf41748>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x1a2cf41780>,
#  'faith': <gensim.models.keyedvectors.Vocab at 0x1a2cf417b8>,
#  'relev': <gensim.models.keyedvectors.Vocab at 0x1a2cf417f0>,
#  'inher': <gensim.models.keyedvectors.Vocab at 0x1a2cf41828>,
#  'metaphys': <gensim.models.keyedvectors.Vocab at 0x1a2cf41860>,
#  'multipl': <gensim.models.keyedvectors.Vocab at 0x1a2cf41898>,
#  'absolut': <gensim.models.keyedvectors.Vocab at 0x1a2cf418d0>,
#  'theolog': <gensim.models.keyedvectors.Vocab at 0x1a2cf41908>,
#  'undoubt': <gensim.models.keyedvectors.Vocab at 0x1a2cf41940>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x1a2cf41978>,
#  'parent': <gensim.models.keyedvectors.Vocab at 0x1a2cf419b0>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x1a2cf419e8>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x1a2cf41a20>,
#  'swear': <gensim.models.keyedvectors.Vocab at 0x1a2cf41a58>,
#  'assum': <gensim.models.keyedvectors.Vocab at 0x1a2cf41a90>,
#  'simpli': <gensim.models.keyedvectors.Vocab at 0x1a2cf41ac8>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x1a2cf41b00>,
#  'trooper': <gensim.models.keyedvectors.Vocab at 0x1a2cf41b38>,
#  'pub': <gensim.models.keyedvectors.Vocab at 0x1a2cf41b70>,
#  'bar': <gensim.models.keyedvectors.Vocab at 0x1a2cf41ba8>,
#  'children': <gensim.models.keyedvectors.Vocab at 0x1a2cf41be0>,
#  'disobey': <gensim.models.keyedvectors.Vocab at 0x1a2cf41c18>,
#  'inappropri': <gensim.models.keyedvectors.Vocab at 0x1a2cf41c50>,
#  'quit': <gensim.models.keyedvectors.Vocab at 0x1a2cf41c88>,
#  'happi': <gensim.models.keyedvectors.Vocab at 0x1a2cf41cc0>,
#  'anim': <gensim.models.keyedvectors.Vocab at 0x1a2cf41cf8>,
#  'analog': <gensim.models.keyedvectors.Vocab at 0x1a2cf41d30>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x1a2cf41d68>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x1a2cf41da0>,
#  'gist': <gensim.models.keyedvectors.Vocab at 0x1a2cf41dd8>,
#  'incident': <gensim.models.keyedvectors.Vocab at 0x1a2cf41e10>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x1a2cf41e48>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x1a2cf41e80>,
#  'older': <gensim.models.keyedvectors.Vocab at 0x1a2cf41eb8>,
#  'piaget': <gensim.models.keyedvectors.Vocab at 0x1a2cf41ef0>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x1a2cf41f28>,
#  'religion': <gensim.models.keyedvectors.Vocab at 0x1a2cf41f60>,
#  'oh': <gensim.models.keyedvectors.Vocab at 0x1a2cf41f98>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x1a2cf41fd0>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x1a2cf44048>,
#  'cri': <gensim.models.keyedvectors.Vocab at 0x1a2cf44080>,
#  'swam': <gensim.models.keyedvectors.Vocab at 0x1a2cf440b8>,
#  'rodc': <gensim.models.keyedvectors.Vocab at 0x1a2cf440f0>,
#  'fc': <gensim.models.keyedvectors.Vocab at 0x1a2cf44128>,
#  'hp': <gensim.models.keyedvectors.Vocab at 0x1a2cf44160>,
#  'rod': <gensim.models.keyedvectors.Vocab at 0x1a2cf44198>,
#  'cerkoney': <gensim.models.keyedvectors.Vocab at 0x1a2cf441d0>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x1a2cf44208>,
#  'qxf': <gensim.models.keyedvectors.Vocab at 0x1a2cf44240>,
#  'hewlett': <gensim.models.keyedvectors.Vocab at 0x1a2cf44278>,
#  'packard': <gensim.models.keyedvectors.Vocab at 0x1a2cf442b0>,
#  'fort': <gensim.models.keyedvectors.Vocab at 0x1a2cf442e8>,
#  'collin': <gensim.models.keyedvectors.Vocab at 0x1a2cf44320>,
#  'co': <gensim.models.keyedvectors.Vocab at 0x1a2cf44358>,
#  'regard': <gensim.models.keyedvectors.Vocab at 0x1a2cf44390>,
#  'ms': <gensim.models.keyedvectors.Vocab at 0x1a2cf443c8>,
#  'east': <gensim.models.keyedvectors.Vocab at 0x1a2cf44400>,
#  'harmoni': <gensim.models.keyedvectors.Vocab at 0x1a2cf44438>,
#  'rd': <gensim.models.keyedvectors.Vocab at 0x1a2cf44470>,
#  'hpdesk': <gensim.models.keyedvectors.Vocab at 0x1a2cf444a8>,
#  'dbm': <gensim.models.keyedvectors.Vocab at 0x1a2cf444e0>,
#  'tm': <gensim.models.keyedvectors.Vocab at 0x1a2cf44518>,
#  'lerc': <gensim.models.keyedvectors.Vocab at 0x1a2cf44550>,
#  'nasa': <gensim.models.keyedvectors.Vocab at 0x1a2cf44588>,
#  'gov': <gensim.models.keyedvectors.Vocab at 0x1a2cf445c0>,
#  'mckissock': <gensim.models.keyedvectors.Vocab at 0x1a2cf445f8>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x1a2cf44630>,
#  'station': <gensim.models.keyedvectors.Vocab at 0x1a2cf44668>,
#  'redesign': <gensim.models.keyedvectors.Vocab at 0x1a2cf446a0>,
#  'jsc': <gensim.models.keyedvectors.Vocab at 0x1a2cf446d8>,
#  'altern': <gensim.models.keyedvectors.Vocab at 0x1a2cf44710>,
#  'lewi': <gensim.models.keyedvectors.Vocab at 0x1a2cf44748>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x1a2cf44780>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x1a2cf447b8>,
#  'cleveland': <gensim.models.keyedvectors.Vocab at 0x1a2cf447f0>,
#  'ohio': <gensim.models.keyedvectors.Vocab at 0x1a2cf44828>,
#  'vax': <gensim.models.keyedvectors.Vocab at 0x1a2cf44860>,
#  'vm': <gensim.models.keyedvectors.Vocab at 0x1a2cf44898>,
#  'vnew': <gensim.models.keyedvectors.Vocab at 0x1a2cf448d0>,
#  'aio': <gensim.models.keyedvectors.Vocab at 0x1a2cf44908>,
#  'kjenk': <gensim.models.keyedvectors.Vocab at 0x1a2cf44940>,
#  'gothamc': <gensim.models.keyedvectors.Vocab at 0x1a2cf44978>,
#  'descript': <gensim.models.keyedvectors.Vocab at 0x1a2cf449b0>,
#  'extern': <gensim.models.keyedvectors.Vocab at 0x1a2cf449e8>,
#  'tank': <gensim.models.keyedvectors.Vocab at 0x1a2cf44a20>,
#  'option': <gensim.models.keyedvectors.Vocab at 0x1a2cf44a58>,
#  'ssf': <gensim.models.keyedvectors.Vocab at 0x1a2cf44a90>,
#  'mark': <gensim.models.keyedvectors.Vocab at 0x1a2cf44ac8>,
#  'propos': <gensim.models.keyedvectors.Vocab at 0x1a2cf44b00>,
#  'shea': <gensim.models.keyedvectors.Vocab at 0x1a2cf44b38>,
#  'committe': <gensim.models.keyedvectors.Vocab at 0x1a2cf44b70>,
#  'crystal': <gensim.models.keyedvectors.Vocab at 0x1a2cf44ba8>,
#  'citi': <gensim.models.keyedvectors.Vocab at 0x1a2cf44be0>,
#  'warmli': <gensim.models.keyedvectors.Vocab at 0x1a2cf44c18>,
#  'receiv': <gensim.models.keyedvectors.Vocab at 0x1a2cf44c50>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x1a2cf44c88>,
#  'wingless': <gensim.models.keyedvectors.Vocab at 0x1a2cf44cc0>,
#  'orbit': <gensim.models.keyedvectors.Vocab at 0x1a2cf44cf8>,
#  'yo': <gensim.models.keyedvectors.Vocab at 0x1a2cf44d30>,
#  'ken': <gensim.models.keyedvectors.Vocab at 0x1a2cf44d68>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x1a2cf44da0>,
#  'edit': <gensim.models.keyedvectors.Vocab at 0x1a2cf44dd8>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x1a2cf44e10>,
#  'connor': <gensim.models.keyedvectors.Vocab at 0x1a2cf44e48>,
#  'panel': <gensim.models.keyedvectors.Vocab at 0x1a2cf44e80>,
#  'giant': <gensim.models.keyedvectors.Vocab at 0x1a2cf44eb8>,
#  'fuel': <gensim.models.keyedvectors.Vocab at 0x1a2cf44ef0>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x1a2cf44f28>,
#  'wing': <gensim.models.keyedvectors.Vocab at 0x1a2cf44f60>,
#  'tail': <gensim.models.keyedvectors.Vocab at 0x1a2cf44f98>,
#  'remov': <gensim.models.keyedvectors.Vocab at 0x1a2cf44fd0>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x1a2cf48048>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x1a2cf48080>,
#  'advisori': <gensim.models.keyedvectors.Vocab at 0x1a2cf480b8>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x1a2cf480f0>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x1a2cf48128>,
#  'modular': <gensim.models.keyedvectors.Vocab at 0x1a2cf48160>,
#  'approach': <gensim.models.keyedvectors.Vocab at 0x1a2cf48198>,
#  'studi': <gensim.models.keyedvectors.Vocab at 0x1a2cf481d0>,
#  'team': <gensim.models.keyedvectors.Vocab at 0x1a2cf48208>,
#  'msfc': <gensim.models.keyedvectors.Vocab at 0x1a2cf48240>,
#  'larc': <gensim.models.keyedvectors.Vocab at 0x1a2cf48278>,
#  'srt': <gensim.models.keyedvectors.Vocab at 0x1a2cf482b0>,
#  'reston': <gensim.models.keyedvectors.Vocab at 0x1a2cf482e8>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x1a2cf48320>,
#  'locat': <gensim.models.keyedvectors.Vocab at 0x1a2cf48358>,
#  'respect': <gensim.models.keyedvectors.Vocab at 0x1a2cf48390>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x1a2cf483c8>,
#  'featur': <gensim.models.keyedvectors.Vocab at 0x1a2cf48400>,
#  'bu': <gensim.models.keyedvectors.Vocab at 0x1a2cf48438>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x1a2cf48470>,
#  'lockhe': <gensim.models.keyedvectors.Vocab at 0x1a2cf484a8>,
#  'qualifi': <gensim.models.keyedvectors.Vocab at 0x1a2cf484e0>,
#  'elv': <gensim.models.keyedvectors.Vocab at 0x1a2cf48518>,
#  'provid': <gensim.models.keyedvectors.Vocab at 0x1a2cf48550>,
#  'propuls': <gensim.models.keyedvectors.Vocab at 0x1a2cf48588>,
#  'gn': <gensim.models.keyedvectors.Vocab at 0x1a2cf485c0>,
#  'manag': <gensim.models.keyedvectors.Vocab at 0x1a2cf485f8>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x1a2cf48630>,
#  'forc': <gensim.models.keyedvectors.Vocab at 0x1a2cf48668>,
#  'capabl': <gensim.models.keyedvectors.Vocab at 0x1a2cf486a0>,
#  'obtain': <gensim.models.keyedvectors.Vocab at 0x1a2cf486d8>,
#  'flight': <gensim.models.keyedvectors.Vocab at 0x1a2cf48710>,
#  'solar': <gensim.models.keyedvectors.Vocab at 0x1a2cf48748>,
#  'array': <gensim.models.keyedvectors.Vocab at 0x1a2cf48780>,
#  'kw': <gensim.models.keyedvectors.Vocab at 0x1a2cf487b8>,
#  'vehicl': <gensim.models.keyedvectors.Vocab at 0x1a2cf487f0>,
#  'fli': <gensim.models.keyedvectors.Vocab at 0x1a2cf48828>,
#  'arrow': <gensim.models.keyedvectors.Vocab at 0x1a2cf48860>,
#  'optim': <gensim.models.keyedvectors.Vocab at 0x1a2cf48898>,
#  'micrograv': <gensim.models.keyedvectors.Vocab at 0x1a2cf488d0>,
#  'environ': <gensim.models.keyedvectors.Vocab at 0x1a2cf48908>,
#  'spacelab': <gensim.models.keyedvectors.Vocab at 0x1a2cf48940>,
#  'mission': <gensim.models.keyedvectors.Vocab at 0x1a2cf48978>,
#  'sourc': <gensim.models.keyedvectors.Vocab at 0x1a2cf489b0>,
#  'tend': <gensim.models.keyedvectors.Vocab at 0x1a2cf489e8>,
#  'oppos': <gensim.models.keyedvectors.Vocab at 0x1a2cf48a20>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x1a2cf48a58>,
#  'sexist': <gensim.models.keyedvectors.Vocab at 0x1a2cf48a90>,
#  'achiev': <gensim.models.keyedvectors.Vocab at 0x1a2cf48ac8>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x1a2cf48b00>,
#  'modul': <gensim.models.keyedvectors.Vocab at 0x1a2cf48b38>,
#  'modifi': <gensim.models.keyedvectors.Vocab at 0x1a2cf48b70>,
#  'lab': <gensim.models.keyedvectors.Vocab at 0x1a2cf48ba8>,
#  'dock': <gensim.models.keyedvectors.Vocab at 0x1a2cf48be0>,
#  'port': <gensim.models.keyedvectors.Vocab at 0x1a2cf48c18>,
#  'intern': <gensim.models.keyedvectors.Vocab at 0x1a2cf48c50>,
#  'partner': <gensim.models.keyedvectors.Vocab at 0x1a2cf48c88>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x1a2cf48cc0>,
#  'node': <gensim.models.keyedvectors.Vocab at 0x1a2cf48cf8>,
#  'habit': <gensim.models.keyedvectors.Vocab at 0x1a2cf48d30>,
#  'eva': <gensim.models.keyedvectors.Vocab at 0x1a2cf48d68>,
#  'nasda': <gensim.models.keyedvectors.Vocab at 0x1a2cf48da0>,
#  'esa': <gensim.models.keyedvectors.Vocab at 0x1a2cf48dd8>,
#  'perman': <gensim.models.keyedvectors.Vocab at 0x1a2cf48e10>,
#  'presenc': <gensim.models.keyedvectors.Vocab at 0x1a2cf48e48>,
#  'acrv': <gensim.models.keyedvectors.Vocab at 0x1a2cf48e80>,
#  'assur': <gensim.models.keyedvectors.Vocab at 0x1a2cf48eb8>,
#  'return': <gensim.models.keyedvectors.Vocab at 0x1a2cf48ef0>,
#  'freedom': <gensim.models.keyedvectors.Vocab at 0x1a2cf48f28>,
#  'deriv': <gensim.models.keyedvectors.Vocab at 0x1a2cf48f60>,
#  'mike': <gensim.models.keyedvectors.Vocab at 0x1a2cf48f98>,
#  'griffin': <gensim.models.keyedvectors.Vocab at 0x1a2cf48fd0>,
#  'alot': <gensim.models.keyedvectors.Vocab at 0x1a2cf4a048>,
#  'lightweight': <gensim.models.keyedvectors.Vocab at 0x1a2cf4a080>,
#  'assembl': <gensim.models.keyedvectors.Vocab at 0x1a2cf4a0b8>,
#  'inclin': <gensim.models.keyedvectors.Vocab at 0x1a2cf4a0f0>,
#  'occur': <gensim.models.keyedvectors.Vocab at 0x1a2cf4a128>,
#  ...}

# %% [markdown]
# This is the vector for the word "car":

# %%
model.wv['car']
# Out:
# array([ 3.0149181e+00,  3.4787848e+00,  1.3744807e+00,  1.4684216e+00,
#        -2.5903833e+00, -3.1519880e+00, -4.1504889e+00,  2.2451546e+00,
#        -1.5356789e+00,  1.0744878e+00, -2.0762601e+00, -1.9990988e+00,
#         7.8651035e-01, -2.2692094e+00,  1.4802520e+00,  1.3099872e+00,
#        -4.4425554e+00, -3.0555847e-01, -3.1820889e+00, -5.2851143e+00,
#        -2.9989252e+00, -6.5653855e-01,  4.4279890e+00,  1.5355009e-01,
#        -5.7501669e+00, -1.9123240e+00, -1.9906388e-01, -1.4370259e+00,
#         3.2023165e-01,  1.5755341e+00, -1.3583846e+00, -1.0737414e+00,
#         8.2900530e-01, -4.9709005e+00,  3.3249788e+00,  2.2614090e+00,
#         4.0890727e-06, -1.9892337e-02, -1.5423027e+00,  2.3841318e-01,
#        -1.0772984e+00,  2.5773036e+00,  1.9911669e+00,  2.6654141e+00,
#        -1.0312412e+00, -4.1696601e+00,  7.0407271e-01,  2.6111569e+00,
#        -3.8363812e+00, -4.5188814e-01,  1.2628269e-01, -2.8677020e+00,
#         4.6998715e+00,  2.1673179e-01, -1.2232567e+00, -1.3001294e+00,
#         3.1775174e-01, -1.5693164e+00,  4.2787490e+00,  3.6678400e+00,
#         1.2142344e+00, -1.0113868e+00, -2.3026588e+00, -2.7460985e+00,
#        -2.2797997e+00, -2.4450207e+00, -5.0720525e-01, -1.3656301e+00,
#        -2.5336535e+00,  1.4234827e+00, -1.3698450e+00,  1.0432004e+00,
#         5.9708530e-01,  1.5590117e+00,  2.9789028e+00, -1.6615812e+00,
#        -6.0160482e-01, -5.4464889e-01, -1.7863023e+00, -3.1491067e+00,
#         8.8454342e+00, -4.0700200e-01,  1.7049097e+00, -3.9378319e+00,
#         7.6241262e-02, -2.9806659e+00,  3.6946676e+00, -1.9850562e+00,
#         4.6358318e+00,  2.7754622e+00, -1.9315271e+00, -7.0278549e-01,
#        -8.9169091e-01,  2.4685850e+00,  4.4470081e+00, -4.1887456e-01,
#         3.5947392e+00, -1.1728626e+00, -1.0046959e+00,  3.1034524e+00],
#       dtype=float32)

# %% [markdown]
# Now let's try to look up words similar to the word "car"

# %%
model.wv.similar_by_word('car', topn = 5)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('nissan', 0.6621789932250977),
#  ('toyota', 0.6598957180976868),
#  ('driven', 0.6593411564826965),
#  ('wagon', 0.6563270688056946),
#  ('dealership', 0.6523199081420898)]

# %% [markdown]
# ### Similarity between two words in the vocabulary

# %% [markdown]
# We can also use the Word2Vec model to return the similarity between two words that are present in the vocabulary.

# %%
model.wv.similarity(w1="car",w2="bike")
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.5462671

# %%
model.wv.similarity(w1="car",w2="car")
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 1.0

# %%
model.wv.similarity(w1="car",w2="hard")
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.09504748

# %% [markdown]
# ## Bag of Words
# Now let's have a look at the BoW model. In some situations, using BoW may be better than Word Embedding, for example:
# 1. Building an baseline model. By using scikit-learn, you need just a few lines of code to build model.
# 2. If your dataset is small and context is domain specific. Context is very domain specific means that you cannot find corresponding Vector from pre-trained word embedding models (GloVe, fastText etc).

# %% [markdown]
# Below are some simple ways to build BoW models:

# %% [markdown]
# ## Count Occurrences
# Counting word occurrences. The reason behind using this approach is that keywords or important signals occur repeatedly. So the number of occurrences can represent the importance of word. For example:

# %%
# example sentence
doc = "In the-state-of-art of the NLP field, Embedding is the \
success way to resolve text related problem and outperform \
Bag of Words ( BoW ). Indeed, BoW introduced limitations \
large feature dimension, sparse representation etc."

# %%
# Initialize a CountVectorizer object
count_vec = CountVectorizer()

# Transforms the data into a bag of words (sparse matrix)
count_occurs = count_vec.fit_transform([doc])

# Create a table to count occurrences of each word
count_occur_df = pd.DataFrame((count, word) for word, count in 
                              zip(count_occurs.toarray().tolist()[0], count_vec.get_feature_names()))
count_occur_df.columns = ['Word', 'Count']
count_occur_df.sort_values('Count', ascending=False, inplace=True)
count_occur_df.head(10)
# Out:
#        Word  Count
# 16       of      3
# 26      the      3
# 3       bow      2
# 0       and      1
# 28      way      1
# 27       to      1
# 25     text      1
# 24  success      1
# 23    state      1
# 22   sparse      1

# %% [markdown]
# ## Normalized Count Occurrences
# Normalization can be applied to avoid model bias. For example:

# %%
# Initialize a TfidfVectorizer object
norm_count_vec = TfidfVectorizer(use_idf=False, norm='l2')

# Transforms the data into a bag of words (sparse matrix)
norm_count_occurs = norm_count_vec.fit_transform([doc])

# Create a table to count occurrences of each word
norm_count_occur_df = pd.DataFrame((count, word) for word, count in 
                                   zip(norm_count_occurs.toarray().tolist()[0], norm_count_vec.get_feature_names()))
norm_count_occur_df.columns = ['Word', 'Count']
norm_count_occur_df.sort_values('Count', ascending=False, inplace=True)
norm_count_occur_df.head(10)
# Out:
#        Word     Count
# 16       of  0.428571
# 26      the  0.428571
# 3       bow  0.285714
# 0       and  0.142857
# 28      way  0.142857
# 27       to  0.142857
# 25     text  0.142857
# 24  success  0.142857
# 23    state  0.142857
# 22   sparse  0.142857

# %% [markdown]
# Now let's evaluate the two BoW models:

# %%
print('Using Count Vectorizer:')
model_pipeline = pipeline(x_train, y_train, mode='count')

print('\nUsing TF Vectorizer:')
model_pipeline = pipeline(x_train, y_train, mode='tf')
# Out:
# Using Count Vectorizer:
# Accuracy: 0.8951 (+/- 0.0113)
#
# Using TF Vectorizer:
# Accuracy: 0.8564 (+/- 0.0161)
