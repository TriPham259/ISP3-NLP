# %%
import pandas as pd
import numpy as np

from sklearn.pipeline import Pipeline
from gensim.models import word2vec
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score, KFold

# %% [markdown]
# ## Dataset

# %%
from sklearn.datasets import fetch_20newsgroups
train_raw_df = fetch_20newsgroups(subset='train', data_home='./scikit_learn_data')
x_train = train_raw_df.data
y_train = train_raw_df.target
# Out:
# Downloading 20news dataset. This may take a few minutes.
# Downloading dataset from https://ndownloader.figshare.com/files/5975967 (14 MB)

# %% [markdown]
# Now we write the required functions to process our dataset.

# %%
# library for cleaning texts
import re

# download the list of all non-significant/irrelevant words
import nltk
nltk.download('stopwords', download_dir='/usr/local/share/nltk_data')
from nltk.corpus import stopwords

# library for stemming (filter out the base form of the words)
from nltk.stem.porter import PorterStemmer

# cleaning one sentence of the dataset
def cleaning(sentence):
    # replace all characters except letters in dataset with ' '
    tokens = re.sub('[^a-zA-Z]', ' ', sentence)

    # change all letters to lower case
    tokens = tokens.lower()

    # split the sentence into a list of words
    tokens = tokens.split()
    
    # remove irrelevant words
    ps = PorterStemmer()
    tokens = [ps.stem(word) for word in tokens if not word in set(stopwords.words('english'))]
    
    # return the sentence as a list of words
    return tokens

# create a list of lists containing words from each sentence
def preprocess_wv(x):
    corpus = [cleaning(sentence) for sentence in x]   
    return corpus

# create a corpus of cleaned sentences for BoW models
def preprocess_bow(x):
    corpus = [' '.join(cleaning(sentence)) for sentence in x]   
    return corpus

# build BoW models from the corpus
def build_model(mode):
    # choose which type of model to use
    vect = None
    if mode == 'count':
        vect = CountVectorizer()
    elif mode == 'tf':
        vect = TfidfVectorizer(use_idf=False, norm='l2')
    else:
        raise ValueError('Mode should be either count or tfidf')
    
    return Pipeline([
        ('vect', vect),
        ('clf' , LogisticRegression(solver='newton-cg',n_jobs=-1))
    ])

# process our dataset
def pipeline(x, y, mode):
    processed_x = preprocess_bow(x)
    
    model_pipeline = build_model(mode)
    cv = KFold(n_splits=5, shuffle=True)
    
    scores = cross_val_score(model_pipeline, processed_x, y, cv=cv, scoring='accuracy')
    print("Accuracy: %0.4f (+/- %0.4f)" % (scores.mean(), scores.std() * 2))
    
    return model_pipeline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /usr/local/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Training the Word2Vec model

# %% [markdown]
# Let's build the vocabulary and train the Word2Vec model.

# %%
documents = preprocess_wv(x_train)
model = word2vec.Word2Vec(documents, size=100, window=10, min_count=2, workers=4)
model.train(documents, total_examples=len(documents), epochs=10)
# Out:
# (19806945, 21334320)

# %% [markdown]
# ## Let's look at some output

# %% [markdown]
# This is the vocabulary of our dataset:

# %%
model.wv.vocab
# Out:
# {'lerxst': <gensim.models.keyedvectors.Vocab at 0x1a235342b0>,
#  'wam': <gensim.models.keyedvectors.Vocab at 0x1a23534748>,
#  'umd': <gensim.models.keyedvectors.Vocab at 0x1a2354b0f0>,
#  'edu': <gensim.models.keyedvectors.Vocab at 0x1a2354bcf8>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x1a2354b6d8>,
#  'subject': <gensim.models.keyedvectors.Vocab at 0x1a2354bac8>,
#  'car': <gensim.models.keyedvectors.Vocab at 0x1a2354b278>,
#  'nntp': <gensim.models.keyedvectors.Vocab at 0x1a2354b978>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x1a2354bc50>,
#  'host': <gensim.models.keyedvectors.Vocab at 0x1a23547da0>,
#  'rac': <gensim.models.keyedvectors.Vocab at 0x1a23547be0>,
#  'organ': <gensim.models.keyedvectors.Vocab at 0x1a235470b8>,
#  'univers': <gensim.models.keyedvectors.Vocab at 0x1a235478d0>,
#  'maryland': <gensim.models.keyedvectors.Vocab at 0x1a235474e0>,
#  'colleg': <gensim.models.keyedvectors.Vocab at 0x1a23547f28>,
#  'park': <gensim.models.keyedvectors.Vocab at 0x1a23547320>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x1a235785c0>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x1a23578978>,
#  'anyon': <gensim.models.keyedvectors.Vocab at 0x1a23589518>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x1a23589a20>,
#  'enlighten': <gensim.models.keyedvectors.Vocab at 0x1a23589470>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x1a23589320>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x1a235896d8>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x1a23589198>,
#  'sport': <gensim.models.keyedvectors.Vocab at 0x1a23589080>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x1a235895c0>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x1a23589780>,
#  'earli': <gensim.models.keyedvectors.Vocab at 0x1a23589208>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x1a23589898>,
#  'bricklin': <gensim.models.keyedvectors.Vocab at 0x1a23589128>,
#  'realli': <gensim.models.keyedvectors.Vocab at 0x1a235897b8>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x1a23589390>,
#  'addit': <gensim.models.keyedvectors.Vocab at 0x1a2358b4a8>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x1a2358b390>,
#  'bumper': <gensim.models.keyedvectors.Vocab at 0x1a2358b588>,
#  'separ': <gensim.models.keyedvectors.Vocab at 0x1a2358bbe0>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x1a2358bd30>,
#  'bodi': <gensim.models.keyedvectors.Vocab at 0x1a2358bef0>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x1a2358bc50>,
#  'tellm': <gensim.models.keyedvectors.Vocab at 0x1a2358bf28>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x1a2358b668>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x1a2358be10>,
#  'engin': <gensim.models.keyedvectors.Vocab at 0x1a2358b780>,
#  'spec': <gensim.models.keyedvectors.Vocab at 0x1a2358bd68>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x1a2358b5f8>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x1a2358b978>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x1a2358bda0>,
#  'histori': <gensim.models.keyedvectors.Vocab at 0x1a2358b748>,
#  'whatev': <gensim.models.keyedvectors.Vocab at 0x1a2358b7b8>,
#  'info': <gensim.models.keyedvectors.Vocab at 0x1a2358b828>,
#  'funki': <gensim.models.keyedvectors.Vocab at 0x1a2358b2b0>,
#  'pleas': <gensim.models.keyedvectors.Vocab at 0x1a2358b6d8>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x1a2358b8d0>,
#  'mail': <gensim.models.keyedvectors.Vocab at 0x1a2358b0f0>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x1a2358bc88>,
#  'il': <gensim.models.keyedvectors.Vocab at 0x1a235a06a0>,
#  'brought': <gensim.models.keyedvectors.Vocab at 0x1a235a0cc0>,
#  'neighborhood': <gensim.models.keyedvectors.Vocab at 0x1a2359f198>,
#  'guykuo': <gensim.models.keyedvectors.Vocab at 0x1a2359fa58>,
#  'carson': <gensim.models.keyedvectors.Vocab at 0x1a2359fa20>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x1a2359fcf8>,
#  'washington': <gensim.models.keyedvectors.Vocab at 0x1a2359fc50>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x1a2359fc88>,
#  'kuo': <gensim.models.keyedvectors.Vocab at 0x1a23593128>,
#  'si': <gensim.models.keyedvectors.Vocab at 0x1a235932e8>,
#  'clock': <gensim.models.keyedvectors.Vocab at 0x1a235930b8>,
#  'poll': <gensim.models.keyedvectors.Vocab at 0x1a235a3630>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x1a235a32e8>,
#  'summari': <gensim.models.keyedvectors.Vocab at 0x1a235a3320>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x1a235a34e0>,
#  'keyword': <gensim.models.keyedvectors.Vocab at 0x1a235a3080>,
#  'acceler': <gensim.models.keyedvectors.Vocab at 0x1a235a3518>,
#  'upgrad': <gensim.models.keyedvectors.Vocab at 0x1a235a35f8>,
#  'articl': <gensim.models.keyedvectors.Vocab at 0x1a235a3588>,
#  'shelley': <gensim.models.keyedvectors.Vocab at 0x1a235a3198>,
#  'innc': <gensim.models.keyedvectors.Vocab at 0x1a235a3550>,
#  'fair': <gensim.models.keyedvectors.Vocab at 0x1a235a30b8>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x1a235a34a8>,
#  'brave': <gensim.models.keyedvectors.Vocab at 0x1a235aa630>,
#  'soul': <gensim.models.keyedvectors.Vocab at 0x1a235aaf60>,
#  'oscil': <gensim.models.keyedvectors.Vocab at 0x1a235aaac8>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x1a235aa748>,
#  'experi': <gensim.models.keyedvectors.Vocab at 0x1a235aa080>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x1a235aaf28>,
#  'brief': <gensim.models.keyedvectors.Vocab at 0x1a235aa6d8>,
#  'messag': <gensim.models.keyedvectors.Vocab at 0x1a235aa128>,
#  'detail': <gensim.models.keyedvectors.Vocab at 0x1a235aa588>,
#  'procedur': <gensim.models.keyedvectors.Vocab at 0x1a235aa048>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x1a235aa390>,
#  'speed': <gensim.models.keyedvectors.Vocab at 0x1a235aa828>,
#  'attain': <gensim.models.keyedvectors.Vocab at 0x1a235aa710>,
#  'cpu': <gensim.models.keyedvectors.Vocab at 0x1a235aa7f0>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x1a235aa7b8>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x1a235aae48>,
#  'card': <gensim.models.keyedvectors.Vocab at 0x1a235aaa90>,
#  'adapt': <gensim.models.keyedvectors.Vocab at 0x1a235aa0f0>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x1a235aab00>,
#  'sink': <gensim.models.keyedvectors.Vocab at 0x1a235aaf98>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x1a235b09e8>,
#  'usag': <gensim.models.keyedvectors.Vocab at 0x1a235b0978>,
#  'per': <gensim.models.keyedvectors.Vocab at 0x1a235b0dd8>,
#  'floppi': <gensim.models.keyedvectors.Vocab at 0x1a235b0940>,
#  'disk': <gensim.models.keyedvectors.Vocab at 0x1a235b06d8>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x1a235b0c50>,
#  'especi': <gensim.models.keyedvectors.Vocab at 0x1a235b0128>,
#  'request': <gensim.models.keyedvectors.Vocab at 0x1a235b0c18>,
#  'summar': <gensim.models.keyedvectors.Vocab at 0x1a235b0198>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x1a235b0668>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x1a235b0828>,
#  'network': <gensim.models.keyedvectors.Vocab at 0x1a235b0400>,
#  'knowledg': <gensim.models.keyedvectors.Vocab at 0x1a235b0240>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x1a235b05f8>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x1a235b0c88>,
#  'answer': <gensim.models.keyedvectors.Vocab at 0x1a235b0ba8>,
#  'twilli': <gensim.models.keyedvectors.Vocab at 0x1a235b06a0>,
#  'ec': <gensim.models.keyedvectors.Vocab at 0x1a235b0438>,
#  'ecn': <gensim.models.keyedvectors.Vocab at 0x1a235b0a20>,
#  'purdu': <gensim.models.keyedvectors.Vocab at 0x1a235b0208>,
#  'thoma': <gensim.models.keyedvectors.Vocab at 0x1a235b0080>,
#  'willi': <gensim.models.keyedvectors.Vocab at 0x1a235b0a58>,
#  'pb': <gensim.models.keyedvectors.Vocab at 0x1a235b0cc0>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x1a235b0748>,
#  'comput': <gensim.models.keyedvectors.Vocab at 0x1a235b0908>,
#  'distribut': <gensim.models.keyedvectors.Vocab at 0x1a23594828>,
#  'usa': <gensim.models.keyedvectors.Vocab at 0x1a235940b8>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x1a235942b0>,
#  'folk': <gensim.models.keyedvectors.Vocab at 0x1a23594470>,
#  'mac': <gensim.models.keyedvectors.Vocab at 0x1a235945f8>,
#  'plu': <gensim.models.keyedvectors.Vocab at 0x1a235c1048>,
#  'gave': <gensim.models.keyedvectors.Vocab at 0x1a235c1080>,
#  'ghost': <gensim.models.keyedvectors.Vocab at 0x1a235c10b8>,
#  'weekend': <gensim.models.keyedvectors.Vocab at 0x1a235c10f0>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x1a235c1128>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x1a235c1160>,
#  'k': <gensim.models.keyedvectors.Vocab at 0x1a235c1198>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x1a235c11d0>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x1a235c1208>,
#  'sooo': <gensim.models.keyedvectors.Vocab at 0x1a235c1240>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x1a235c1278>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x1a235c12b0>,
#  'machin': <gensim.models.keyedvectors.Vocab at 0x1a235c12e8>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x1a235c1320>,
#  'sooner': <gensim.models.keyedvectors.Vocab at 0x1a235c1358>,
#  'intend': <gensim.models.keyedvectors.Vocab at 0x1a235c1390>,
#  'pick': <gensim.models.keyedvectors.Vocab at 0x1a235c13c8>,
#  'powerbook': <gensim.models.keyedvectors.Vocab at 0x1a235c1400>,
#  'mayb': <gensim.models.keyedvectors.Vocab at 0x1a235c1438>,
#  'bunch': <gensim.models.keyedvectors.Vocab at 0x1a235c1470>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x1a235c14a8>,
#  'somebodi': <gensim.models.keyedvectors.Vocab at 0x1a235c14e0>,
#  'anybodi': <gensim.models.keyedvectors.Vocab at 0x1a235c1518>,
#  'dirt': <gensim.models.keyedvectors.Vocab at 0x1a235c1550>,
#  'round': <gensim.models.keyedvectors.Vocab at 0x1a235c1588>,
#  'introduct': <gensim.models.keyedvectors.Vocab at 0x1a235c15c0>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x1a235c15f8>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x1a235c1630>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x1a235c1668>,
#  'suppos': <gensim.models.keyedvectors.Vocab at 0x1a235c16a0>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x1a235c16d8>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x1a235c1710>,
#  'summer': <gensim.models.keyedvectors.Vocab at 0x1a235c1748>,
#  'anymor': <gensim.models.keyedvectors.Vocab at 0x1a235c1780>,
#  'sinc': <gensim.models.keyedvectors.Vocab at 0x1a235c17b8>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x1a235c17f0>,
#  'macleak': <gensim.models.keyedvectors.Vocab at 0x1a235c1828>,
#  'rumor': <gensim.models.keyedvectors.Vocab at 0x1a235c1860>,
#  'price': <gensim.models.keyedvectors.Vocab at 0x1a235c1898>,
#  'drop': <gensim.models.keyedvectors.Vocab at 0x1a235c18d0>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x1a235c1908>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x1a235c1940>,
#  'duo': <gensim.models.keyedvectors.Vocab at 0x1a235c1978>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x1a235c19b0>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x1a235c19e8>,
#  'impress': <gensim.models.keyedvectors.Vocab at 0x1a235c1a20>,
#  'display': <gensim.models.keyedvectors.Vocab at 0x1a235c1a58>,
#  'probabl': <gensim.models.keyedvectors.Vocab at 0x1a235c1a90>,
#  'swing': <gensim.models.keyedvectors.Vocab at 0x1a235c1ac8>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x1a235c1b00>,
#  'mb': <gensim.models.keyedvectors.Vocab at 0x1a235c1b38>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x1a235c1b70>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x1a235c1ba8>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x1a235c1be0>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x1a235c1c18>,
#  'yea': <gensim.models.keyedvectors.Vocab at 0x1a235c1c50>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x1a235c1c88>,
#  'store': <gensim.models.keyedvectors.Vocab at 0x1a235c1cc0>,
#  'wow': <gensim.models.keyedvectors.Vocab at 0x1a235c1cf8>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x1a235c1d30>,
#  'solicit': <gensim.models.keyedvectors.Vocab at 0x1a235c1d68>,
#  'opinion': <gensim.models.keyedvectors.Vocab at 0x1a235c1da0>,
#  'peopl': <gensim.models.keyedvectors.Vocab at 0x1a235c1dd8>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x1a235c1e10>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x1a235c1e48>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x1a235c1e80>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x1a235c1eb8>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x1a235c1ef0>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x1a235c1f28>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x1a235c1f60>,
#  'activ': <gensim.models.keyedvectors.Vocab at 0x1a235c1f98>,
#  'realiz': <gensim.models.keyedvectors.Vocab at 0x1a235c1fd0>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x1a235c3048>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x1a235c3080>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x1a235c30b8>,
#  'breifli': <gensim.models.keyedvectors.Vocab at 0x1a235c30f0>,
#  'figur': <gensim.models.keyedvectors.Vocab at 0x1a235c3128>,
#  'actual': <gensim.models.keyedvectors.Vocab at 0x1a235c3160>,
#  'daili': <gensim.models.keyedvectors.Vocab at 0x1a235c3198>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x1a235c31d0>,
#  'prove': <gensim.models.keyedvectors.Vocab at 0x1a235c3208>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x1a235c3240>,
#  'hellcat': <gensim.models.keyedvectors.Vocab at 0x1a235c3278>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x1a235c32b0>,
#  'advanc': <gensim.models.keyedvectors.Vocab at 0x1a235c32e8>,
#  'email': <gensim.models.keyedvectors.Vocab at 0x1a235c3320>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x1a235c3358>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x1a235c3390>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x1a235c33c8>,
#  'premium': <gensim.models.keyedvectors.Vocab at 0x1a235c3400>,
#  'corner': <gensim.models.keyedvectors.Vocab at 0x1a235c3438>,
#  'tom': <gensim.models.keyedvectors.Vocab at 0x1a235c3470>,
#  'electr': <gensim.models.keyedvectors.Vocab at 0x1a235c34a8>,
#  'convict': <gensim.models.keyedvectors.Vocab at 0x1a235c34e0>,
#  'danger': <gensim.models.keyedvectors.Vocab at 0x1a235c3518>,
#  'enemi': <gensim.models.keyedvectors.Vocab at 0x1a235c3550>,
#  'truth': <gensim.models.keyedvectors.Vocab at 0x1a235c3588>,
#  'lie': <gensim.models.keyedvectors.Vocab at 0x1a235c35c0>,
#  'f': <gensim.models.keyedvectors.Vocab at 0x1a235c35f8>,
#  'w': <gensim.models.keyedvectors.Vocab at 0x1a235c3630>,
#  'nietzsch': <gensim.models.keyedvectors.Vocab at 0x1a235c3668>,
#  'jgreen': <gensim.models.keyedvectors.Vocab at 0x1a235c36a0>,
#  'amber': <gensim.models.keyedvectors.Vocab at 0x1a235c36d8>,
#  'joe': <gensim.models.keyedvectors.Vocab at 0x1a235c3710>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x1a235c3748>,
#  'weitek': <gensim.models.keyedvectors.Vocab at 0x1a235c3780>,
#  'p': <gensim.models.keyedvectors.Vocab at 0x1a235c37b8>,
#  'harri': <gensim.models.keyedvectors.Vocab at 0x1a235c37f0>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x1a235c3828>,
#  'divis': <gensim.models.keyedvectors.Vocab at 0x1a235c3860>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x1a235c3898>,
#  'ssd': <gensim.models.keyedvectors.Vocab at 0x1a235c38d0>,
#  'csd': <gensim.models.keyedvectors.Vocab at 0x1a235c3908>,
#  'com': <gensim.models.keyedvectors.Vocab at 0x1a235c3940>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x1a235c3978>,
#  'newsread': <gensim.models.keyedvectors.Vocab at 0x1a235c39b0>,
#  'tin': <gensim.models.keyedvectors.Vocab at 0x1a235c39e8>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x1a235c3a20>,
#  'pl': <gensim.models.keyedvectors.Vocab at 0x1a235c3a58>,
#  'robert': <gensim.models.keyedvectors.Vocab at 0x1a235c3a90>,
#  'j': <gensim.models.keyedvectors.Vocab at 0x1a235c3ac8>,
#  'kyanko': <gensim.models.keyedvectors.Vocab at 0x1a235c3b00>,
#  'rob': <gensim.models.keyedvectors.Vocab at 0x1a235c3b38>,
#  'rjck': <gensim.models.keyedvectors.Vocab at 0x1a235c3b70>,
#  'uucp': <gensim.models.keyedvectors.Vocab at 0x1a235c3ba8>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x1a235c3be0>,
#  'abraxi': <gensim.models.keyedvectors.Vocab at 0x1a235c3c18>,
#  'iastat': <gensim.models.keyedvectors.Vocab at 0x1a235c3c50>,
#  'write': <gensim.models.keyedvectors.Vocab at 0x1a235c3c88>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x1a235c3cc0>,
#  'graphic': <gensim.models.keyedvectors.Vocab at 0x1a235c3cf8>,
#  'chip': <gensim.models.keyedvectors.Vocab at 0x1a235c3d30>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x1a235c3d68>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x1a235c3da0>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x1a235c3dd8>,
#  'stuff': <gensim.models.keyedvectors.Vocab at 0x1a235c3e10>,
#  'goe': <gensim.models.keyedvectors.Vocab at 0x1a235c3e48>,
#  'pretti': <gensim.models.keyedvectors.Vocab at 0x1a235c3e80>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x1a235c3eb8>,
#  'quadrilater': <gensim.models.keyedvectors.Vocab at 0x1a235c3ef0>,
#  'fill': <gensim.models.keyedvectors.Vocab at 0x1a235c3f28>,
#  'command': <gensim.models.keyedvectors.Vocab at 0x1a235c3f60>,
#  'requir': <gensim.models.keyedvectors.Vocab at 0x1a235c3f98>,
#  'four': <gensim.models.keyedvectors.Vocab at 0x1a235c3fd0>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x1a235c7048>,
#  'address': <gensim.models.keyedvectors.Vocab at 0x1a235c7080>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x1a235c70b8>,
#  'inform': <gensim.models.keyedvectors.Vocab at 0x1a235c70f0>,
#  'corpor': <gensim.models.keyedvectors.Vocab at 0x1a235c7128>,
#  'scare': <gensim.models.keyedvectors.Vocab at 0x1a235c7160>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x1a235c7198>,
#  'sens': <gensim.models.keyedvectors.Vocab at 0x1a235c71d0>,
#  'humor': <gensim.models.keyedvectors.Vocab at 0x1a235c7208>,
#  'jonathan': <gensim.models.keyedvectors.Vocab at 0x1a235c7240>,
#  'winter': <gensim.models.keyedvectors.Vocab at 0x1a235c7278>,
#  'jcm': <gensim.models.keyedvectors.Vocab at 0x1a235c72b0>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x1a235c72e8>,
#  'cfa': <gensim.models.keyedvectors.Vocab at 0x1a235c7320>,
#  'harvard': <gensim.models.keyedvectors.Vocab at 0x1a235c7358>,
#  'mcdowel': <gensim.models.keyedvectors.Vocab at 0x1a235c7390>,
#  'shuttl': <gensim.models.keyedvectors.Vocab at 0x1a235c73c8>,
#  'launch': <gensim.models.keyedvectors.Vocab at 0x1a235c7400>,
#  'smithsonian': <gensim.models.keyedvectors.Vocab at 0x1a235c7438>,
#  'astrophys': <gensim.models.keyedvectors.Vocab at 0x1a235c7470>,
#  'observatori': <gensim.models.keyedvectors.Vocab at 0x1a235c74a8>,
#  'cambridg': <gensim.models.keyedvectors.Vocab at 0x1a235c74e0>,
#  'sci': <gensim.models.keyedvectors.Vocab at 0x1a235c7518>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x1a235c7550>,
#  'std': <gensim.models.keyedvectors.Vocab at 0x1a235c7588>,
#  'tombak': <gensim.models.keyedvectors.Vocab at 0x1a235c75c0>,
#  'baker': <gensim.models.keyedvectors.Vocab at 0x1a235c75f8>,
#  'jlwx': <gensim.models.keyedvectors.Vocab at 0x1a235c7630>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x1a235c7668>,
#  'cs': <gensim.models.keyedvectors.Vocab at 0x1a235c76a0>,
#  'cmu': <gensim.models.keyedvectors.Vocab at 0x1a235c76d8>,
#  'etrat': <gensim.models.keyedvectors.Vocab at 0x1a235c7710>,
#  'ttac': <gensim.models.keyedvectors.Vocab at 0x1a235c7748>,
#  'ttu': <gensim.models.keyedvectors.Vocab at 0x1a235c7780>,
#  'pack': <gensim.models.keyedvectors.Vocab at 0x1a235c77b8>,
#  'rat': <gensim.models.keyedvectors.Vocab at 0x1a235c77f0>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x1a235c7828>,
#  'caution': <gensim.models.keyedvectors.Vocab at 0x1a235c7860>,
#  'warn': <gensim.models.keyedvectors.Vocab at 0x1a235c7898>,
#  'memori': <gensim.models.keyedvectors.Vocab at 0x1a235c78d0>,
#  'verifi': <gensim.models.keyedvectors.Vocab at 0x1a235c7908>,
#  'unexpect': <gensim.models.keyedvectors.Vocab at 0x1a235c7940>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x1a235c7978>,
#  'sorri': <gensim.models.keyedvectors.Vocab at 0x1a235c79b0>,
#  'dumb': <gensim.models.keyedvectors.Vocab at 0x1a235c79e8>,
#  'pariti': <gensim.models.keyedvectors.Vocab at 0x1a235c7a20>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x1a235c7a58>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x1a235c7a90>,
#  'condit': <gensim.models.keyedvectors.Vocab at 0x1a235c7ac8>,
#  'waiver': <gensim.models.keyedvectors.Vocab at 0x1a235c7b00>,
#  'ye': <gensim.models.keyedvectors.Vocab at 0x1a235c7b38>,
#  'alreadi': <gensim.models.keyedvectors.Vocab at 0x1a235c7b70>,
#  'knew': <gensim.models.keyedvectors.Vocab at 0x1a235c7ba8>,
#  'curiou': <gensim.models.keyedvectors.Vocab at 0x1a235c7be0>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x1a235c7c18>,
#  'quot': <gensim.models.keyedvectors.Vocab at 0x1a235c7c50>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x1a235c7c88>,
#  'basic': <gensim.models.keyedvectors.Vocab at 0x1a235c7cc0>,
#  'bug': <gensim.models.keyedvectors.Vocab at 0x1a235c7cf8>,
#  'softwar': <gensim.models.keyedvectors.Vocab at 0x1a235c7d30>,
#  'check': <gensim.models.keyedvectors.Vocab at 0x1a235c7d68>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x1a235c7da0>,
#  'valu': <gensim.models.keyedvectors.Vocab at 0x1a235c7dd8>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x1a235c7e10>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x1a235c7e48>,
#  'till': <gensim.models.keyedvectors.Vocab at 0x1a235c7e80>,
#  'suchlik': <gensim.models.keyedvectors.Vocab at 0x1a235c7eb8>,
#  'fix': <gensim.models.keyedvectors.Vocab at 0x1a235c7ef0>,
#  'code': <gensim.models.keyedvectors.Vocab at 0x1a235c7f28>,
#  'possibl': <gensim.models.keyedvectors.Vocab at 0x1a235c7f60>,
#  'introduc': <gensim.models.keyedvectors.Vocab at 0x1a235c7f98>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x1a235c7fd0>,
#  'crew': <gensim.models.keyedvectors.Vocab at 0x1a235cb048>,
#  'ok': <gensim.models.keyedvectors.Vocab at 0x1a235cb080>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x1a235cb0b8>,
#  'liftoff': <gensim.models.keyedvectors.Vocab at 0x1a235cb0f0>,
#  'ignor': <gensim.models.keyedvectors.Vocab at 0x1a235cb128>,
#  'dfo': <gensim.models.keyedvectors.Vocab at 0x1a235cb160>,
#  'vttoulu': <gensim.models.keyedvectors.Vocab at 0x1a235cb198>,
#  'tko': <gensim.models.keyedvectors.Vocab at 0x1a235cb1d0>,
#  'vtt': <gensim.models.keyedvectors.Vocab at 0x1a235cb208>,
#  'fi': <gensim.models.keyedvectors.Vocab at 0x1a235cb240>,
#  'foxvog': <gensim.models.keyedvectors.Vocab at 0x1a235cb278>,
#  'dougla': <gensim.models.keyedvectors.Vocab at 0x1a235cb2b0>,
#  'reword': <gensim.models.keyedvectors.Vocab at 0x1a235cb2e8>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x1a235cb320>,
#  'amend': <gensim.models.keyedvectors.Vocab at 0x1a235cb358>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x1a235cb390>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x1a235cb3c8>,
#  'eu': <gensim.models.keyedvectors.Vocab at 0x1a235cb400>,
#  'transfer': <gensim.models.keyedvectors.Vocab at 0x1a235cb438>,
#  'stratu': <gensim.models.keyedvectors.Vocab at 0x1a235cb470>,
#  'cdt': <gensim.models.keyedvectors.Vocab at 0x1a235cb4a8>,
#  'sw': <gensim.models.keyedvectors.Vocab at 0x1a235cb4e0>,
#  'tavar': <gensim.models.keyedvectors.Vocab at 0x1a235cb518>,
#  'apr': <gensim.models.keyedvectors.Vocab at 0x1a235cb550>,
#  'ousrvr': <gensim.models.keyedvectors.Vocab at 0x1a235cb588>,
#  'oulu': <gensim.models.keyedvectors.Vocab at 0x1a235cb5c0>,
#  'qv': <gensim.models.keyedvectors.Vocab at 0x1a235cb5f8>,
#  'v': <gensim.models.keyedvectors.Vocab at 0x1a235cb630>,
#  'gi': <gensim.models.keyedvectors.Vocab at 0x1a235cb668>,
#  'ulowel': <gensim.models.keyedvectors.Vocab at 0x1a235cb6a0>,
#  'jrutledg': <gensim.models.keyedvectors.Vocab at 0x1a235cb6d8>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x1a235cb710>,
#  'lawrenc': <gensim.models.keyedvectors.Vocab at 0x1a235cb748>,
#  'rutledg': <gensim.models.keyedvectors.Vocab at 0x1a235cb780>,
#  'massiv': <gensim.models.keyedvectors.Vocab at 0x1a235cb7b8>,
#  'destruct': <gensim.models.keyedvectors.Vocab at 0x1a235cb7f0>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x1a235cb828>,
#  'mani': <gensim.models.keyedvectors.Vocab at 0x1a235cb860>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x1a235cb898>,
#  'weapon': <gensim.models.keyedvectors.Vocab at 0x1a235cb8d0>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x1a235cb908>,
#  'accident': <gensim.models.keyedvectors.Vocab at 0x1a235cb940>,
#  'crimial': <gensim.models.keyedvectors.Vocab at 0x1a235cb978>,
#  'mass': <gensim.models.keyedvectors.Vocab at 0x1a235cb9b0>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x1a235cb9e8>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x1a235cba20>,
#  'govern': <gensim.models.keyedvectors.Vocab at 0x1a235cba58>,
#  'individu': <gensim.models.keyedvectors.Vocab at 0x1a235cba90>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x1a235cbac8>,
#  'result': <gensim.models.keyedvectors.Vocab at 0x1a235cbb00>,
#  'needless': <gensim.models.keyedvectors.Vocab at 0x1a235cbb38>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x1a235cbb70>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x1a235cbba8>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x1a235cbbe0>,
#  'bear': <gensim.models.keyedvectors.Vocab at 0x1a235cbc18>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x1a235cbc50>,
#  'exist': <gensim.models.keyedvectors.Vocab at 0x1a235cbc88>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x1a235cbcc0>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x1a235cbcf8>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x1a235cbd30>,
#  'disagre': <gensim.models.keyedvectors.Vocab at 0x1a235cbd68>,
#  'everi': <gensim.models.keyedvectors.Vocab at 0x1a235cbda0>,
#  'count': <gensim.models.keyedvectors.Vocab at 0x1a235cbdd8>,
#  'believ': <gensim.models.keyedvectors.Vocab at 0x1a235cbe10>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x1a235cbe48>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x1a235cbe80>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x1a235cbeb8>,
#  'neighbor': <gensim.models.keyedvectors.Vocab at 0x1a235cbef0>,
#  'nuclear': <gensim.models.keyedvectors.Vocab at 0x1a235cbf28>,
#  'biolog': <gensim.models.keyedvectors.Vocab at 0x1a235cbf60>,
#  'nerv': <gensim.models.keyedvectors.Vocab at 0x1a235cbf98>,
#  'ga': <gensim.models.keyedvectors.Vocab at 0x1a235cbfd0>,
#  'properti': <gensim.models.keyedvectors.Vocab at 0x1a235cf048>,
#  'cannot': <gensim.models.keyedvectors.Vocab at 0x1a235cf080>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x1a235cf0b8>,
#  'agre': <gensim.models.keyedvectors.Vocab at 0x1a235cf0f0>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x1a235cf128>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x1a235cf160>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x1a235cf198>,
#  'blank': <gensim.models.keyedvectors.Vocab at 0x1a235cf1d0>,
#  'cours': <gensim.models.keyedvectors.Vocab at 0x1a235cf208>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x1a235cf240>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x1a235cf278>,
#  'rigidli': <gensim.models.keyedvectors.Vocab at 0x1a235cf2b0>,
#  'defin': <gensim.models.keyedvectors.Vocab at 0x1a235cf2e8>,
#  'bill': <gensim.models.keyedvectors.Vocab at 0x1a235cf320>,
#  'doug': <gensim.models.keyedvectors.Vocab at 0x1a235cf358>,
#  'cbw': <gensim.models.keyedvectors.Vocab at 0x1a235cf390>,
#  'nuke': <gensim.models.keyedvectors.Vocab at 0x1a235cf3c8>,
#  'sarah': <gensim.models.keyedvectors.Vocab at 0x1a235cf400>,
#  'bradi': <gensim.models.keyedvectors.Vocab at 0x1a235cf438>,
#  'street': <gensim.models.keyedvectors.Vocab at 0x1a235cf470>,
#  'sweeper': <gensim.models.keyedvectors.Vocab at 0x1a235cf4a8>,
#  'shotgun': <gensim.models.keyedvectors.Vocab at 0x1a235cf4e0>,
#  'semi': <gensim.models.keyedvectors.Vocab at 0x1a235cf518>,
#  'automat': <gensim.models.keyedvectors.Vocab at 0x1a235cf550>,
#  'sk': <gensim.models.keyedvectors.Vocab at 0x1a235cf588>,
#  'rifl': <gensim.models.keyedvectors.Vocab at 0x1a235cf5c0>,
#  'doubt': <gensim.models.keyedvectors.Vocab at 0x1a235cf5f8>,
#  'allegedli': <gensim.models.keyedvectors.Vocab at 0x1a235cf630>,
#  'immedi': <gensim.models.keyedvectors.Vocab at 0x1a235cf668>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x1a235cf6a0>,
#  'thousand': <gensim.models.keyedvectors.Vocab at 0x1a235cf6d8>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x1a235cf710>,
#  'handgun': <gensim.models.keyedvectors.Vocab at 0x1a235cf748>,
#  'easili': <gensim.models.keyedvectors.Vocab at 0x1a235cf780>,
#  'reduc': <gensim.models.keyedvectors.Vocab at 0x1a235cf7b8>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x1a235cf7f0>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x1a235cf828>,
#  'restrict': <gensim.models.keyedvectors.Vocab at 0x1a235cf860>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x1a235cf898>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x1a235cf8d0>,
#  'argument': <gensim.models.keyedvectors.Vocab at 0x1a235cf908>,
#  'commonli': <gensim.models.keyedvectors.Vocab at 0x1a235cf940>,
#  'understood': <gensim.models.keyedvectors.Vocab at 0x1a235cf978>,
#  'switch': <gensim.models.keyedvectors.Vocab at 0x1a235cf9b0>,
#  'topic': <gensim.models.keyedvectors.Vocab at 0x1a235cf9e8>,
#  'evid': <gensim.models.keyedvectors.Vocab at 0x1a235cfa20>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x1a235cfa58>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x1a235cfa90>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x1a235cfac8>,
#  'analysi': <gensim.models.keyedvectors.Vocab at 0x1a235cfb00>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x1a235cfb38>,
#  'consid': <gensim.models.keyedvectors.Vocab at 0x1a235cfb70>,
#  'anoth': <gensim.models.keyedvectors.Vocab at 0x1a235cfba8>,
#  'rocket': <gensim.models.keyedvectors.Vocab at 0x1a235cfbe0>,
#  'speak': <gensim.models.keyedvectors.Vocab at 0x1a235cfc18>,
#  'compani': <gensim.models.keyedvectors.Vocab at 0x1a235cfc50>,
#  'vo': <gensim.models.keyedvectors.Vocab at 0x1a235cfc88>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x1a235cfcc0>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x1a235cfcf8>,
#  'investor': <gensim.models.keyedvectors.Vocab at 0x1a235cfd30>,
#  'packet': <gensim.models.keyedvectors.Vocab at 0x1a235cfd68>,
#  'bmdelan': <gensim.models.keyedvectors.Vocab at 0x1a235cfda0>,
#  'quad': <gensim.models.keyedvectors.Vocab at 0x1a235cfdd8>,
#  'uchicago': <gensim.models.keyedvectors.Vocab at 0x1a235cfe10>,
#  'brian': <gensim.models.keyedvectors.Vocab at 0x1a235cfe48>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x1a235cfe80>,
#  'delaney': <gensim.models.keyedvectors.Vocab at 0x1a235cfeb8>,
#  'brain': <gensim.models.keyedvectors.Vocab at 0x1a235cfef0>,
#  'tumor': <gensim.models.keyedvectors.Vocab at 0x1a235cff28>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x1a235cff60>,
#  'repli': <gensim.models.keyedvectors.Vocab at 0x1a235cff98>,
#  'midway': <gensim.models.keyedvectors.Vocab at 0x1a235cffd0>,
#  'chicago': <gensim.models.keyedvectors.Vocab at 0x1a235d1048>,
#  'respond': <gensim.models.keyedvectors.Vocab at 0x1a235d1080>,
#  'directli': <gensim.models.keyedvectors.Vocab at 0x1a235d10b8>,
#  'bounc': <gensim.models.keyedvectors.Vocab at 0x1a235d10f0>,
#  'prob': <gensim.models.keyedvectors.Vocab at 0x1a235d1128>,
#  'sean': <gensim.models.keyedvectors.Vocab at 0x1a235d1160>,
#  'debra': <gensim.models.keyedvectors.Vocab at 0x1a235d1198>,
#  'sharon': <gensim.models.keyedvectors.Vocab at 0x1a235d11d0>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x1a235d1208>,
#  'publicli': <gensim.models.keyedvectors.Vocab at 0x1a235d1240>,
#  'everyon': <gensim.models.keyedvectors.Vocab at 0x1a235d1278>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x1a235d12b0>,
#  'glad': <gensim.models.keyedvectors.Vocab at 0x1a235d12e8>,
#  'rn': <gensim.models.keyedvectors.Vocab at 0x1a235d1320>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x1a235d1358>,
#  'rm': <gensim.models.keyedvectors.Vocab at 0x1a235d1390>,
#  'tri': <gensim.models.keyedvectors.Vocab at 0x1a235d13c8>,
#  'delet': <gensim.models.keyedvectors.Vocab at 0x1a235d1400>,
#  'file': <gensim.models.keyedvectors.Vocab at 0x1a235d1438>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x1a235d1470>,
#  'septemb': <gensim.models.keyedvectors.Vocab at 0x1a235d14a8>,
#  'hmmm': <gensim.models.keyedvectors.Vocab at 0x1a235d14e0>,
#  'bgrubb': <gensim.models.keyedvectors.Vocab at 0x1a235d1518>,
#  'dant': <gensim.models.keyedvectors.Vocab at 0x1a235d1550>,
#  'nmsu': <gensim.models.keyedvectors.Vocab at 0x1a235d1588>,
#  'grubb': <gensim.models.keyedvectors.Vocab at 0x1a235d15c0>,
#  'ide': <gensim.models.keyedvectors.Vocab at 0x1a235d15f8>,
#  'vs': <gensim.models.keyedvectors.Vocab at 0x1a235d1630>,
#  'scsi': <gensim.models.keyedvectors.Vocab at 0x1a235d1668>,
#  'mexico': <gensim.models.keyedvectors.Vocab at 0x1a235d16a0>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x1a235d16d8>,
#  'cruce': <gensim.models.keyedvectors.Vocab at 0x1a235d1710>,
#  'nm': <gensim.models.keyedvectors.Vocab at 0x1a235d1748>,
#  'dxb': <gensim.models.keyedvectors.Vocab at 0x1a235d1780>,
#  'psuvm': <gensim.models.keyedvectors.Vocab at 0x1a235d17b8>,
#  'psu': <gensim.models.keyedvectors.Vocab at 0x1a235d17f0>,
#  'qlbrlinn': <gensim.models.keyedvectors.Vocab at 0x1a235d1828>,
#  'rk': <gensim.models.keyedvectors.Vocab at 0x1a235d1860>,
#  'dn': <gensim.models.keyedvectors.Vocab at 0x1a235d1898>,
#  'pc': <gensim.models.keyedvectors.Vocab at 0x1a235d18d0>,
#  'magazin': <gensim.models.keyedvectors.Vocab at 0x1a235d1908>,
#  'april': <gensim.models.keyedvectors.Vocab at 0x1a235d1940>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x1a235d1978>,
#  'twice': <gensim.models.keyedvectors.Vocab at 0x1a235d19b0>,
#  'fasst': <gensim.models.keyedvectors.Vocab at 0x1a235d19e8>,
#  'esdi': <gensim.models.keyedvectors.Vocab at 0x1a235d1a20>,
#  'faster': <gensim.models.keyedvectors.Vocab at 0x1a235d1a58>,
#  'devic': <gensim.models.keyedvectors.Vocab at 0x1a235d1a90>,
#  'accept': <gensim.models.keyedvectors.Vocab at 0x1a235d1ac8>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x1a235d1b00>,
#  'stall': <gensim.models.keyedvectors.Vocab at 0x1a235d1b38>,
#  'incompat': <gensim.models.keyedvectors.Vocab at 0x1a235d1b70>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x1a235d1ba8>,
#  'instal': <gensim.models.keyedvectors.Vocab at 0x1a235d1be0>,
#  'headach': <gensim.models.keyedvectors.Vocab at 0x1a235d1c18>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x1a235d1c50>,
#  'writer': <gensim.models.keyedvectors.Vocab at 0x1a235d1c88>,
#  'stupid': <gensim.models.keyedvectors.Vocab at 0x1a235d1cc0>,
#  'statement': <gensim.models.keyedvectors.Vocab at 0x1a235d1cf8>,
#  'list': <gensim.models.keyedvectors.Vocab at 0x1a235d1d30>,
#  'rang': <gensim.models.keyedvectors.Vocab at 0x1a235d1d68>,
#  'convinc': <gensim.models.keyedvectors.Vocab at 0x1a235d1da0>,
#  'absurd': <gensim.models.keyedvectors.Vocab at 0x1a235d1dd8>,
#  'ii': <gensim.models.keyedvectors.Vocab at 0x1a235d1e10>,
#  'alway': <gensim.models.keyedvectors.Vocab at 0x1a235d1e48>,
#  'standard': <gensim.models.keyedvectors.Vocab at 0x1a235d1e80>,
#  'inde': <gensim.models.keyedvectors.Vocab at 0x1a235d1eb8>,
#  'burst': <gensim.models.keyedvectors.Vocab at 0x1a235d1ef0>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x1a235d1f28>,
#  'increas': <gensim.models.keyedvectors.Vocab at 0x1a235d1f60>,
#  'quadra': <gensim.models.keyedvectors.Vocab at 0x1a235d1f98>,
#  'mode': <gensim.models.keyedvectors.Vocab at 0x1a235d1fd0>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x1a235d5048>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x1a235d5080>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x1a235d50b8>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x1a235d50f0>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x1a235d5128>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x1a235d5160>,
#  'newsgroup': <gensim.models.keyedvectors.Vocab at 0x1a235d5198>,
#  'ibm': <gensim.models.keyedvectors.Vocab at 0x1a235d51d0>,
#  'sheet': <gensim.models.keyedvectors.Vocab at 0x1a235d5208>,
#  'avail': <gensim.models.keyedvectors.Vocab at 0x1a235d5240>,
#  'ftp': <gensim.models.keyedvectors.Vocab at 0x1a235d5278>,
#  'sumex': <gensim.models.keyedvectors.Vocab at 0x1a235d52b0>,
#  'aim': <gensim.models.keyedvectors.Vocab at 0x1a235d52e8>,
#  'stanford': <gensim.models.keyedvectors.Vocab at 0x1a235d5320>,
#  'compar': <gensim.models.keyedvectors.Vocab at 0x1a235d5358>,
#  'txt': <gensim.models.keyedvectors.Vocab at 0x1a235d5390>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x1a235d53c8>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x1a235d5400>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x1a235d5438>,
#  'inconsi': <gensim.models.keyedvectors.Vocab at 0x1a235d5470>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x1a235d54a8>,
#  'document': <gensim.models.keyedvectors.Vocab at 0x1a235d54e0>,
#  'appl': <gensim.models.keyedvectors.Vocab at 0x1a235d5518>,
#  'salesperson': <gensim.models.keyedvectors.Vocab at 0x1a235d5550>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x1a235d5588>,
#  'maximum': <gensim.models.keyedvectors.Vocab at 0x1a235d55c0>,
#  'synchron': <gensim.models.keyedvectors.Vocab at 0x1a235d55f8>,
#  'ansynchron': <gensim.models.keyedvectors.Vocab at 0x1a235d5630>,
#  'slower': <gensim.models.keyedvectors.Vocab at 0x1a235d5668>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x1a235d56a0>,
#  'interfac': <gensim.models.keyedvectors.Vocab at 0x1a235d56d8>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x1a235d5710>,
#  'driven': <gensim.models.keyedvectors.Vocab at 0x1a235d5748>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x1a235d5780>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x1a235d57b8>,
#  'slam': <gensim.models.keyedvectors.Vocab at 0x1a235d57f0>,
#  'refer': <gensim.models.keyedvectors.Vocab at 0x1a235d5828>,
#  'digit': <gensim.models.keyedvectors.Vocab at 0x1a235d5860>,
#  'review': <gensim.models.keyedvectors.Vocab at 0x1a235d5898>,
#  'oct': <gensim.models.keyedvectors.Vocab at 0x1a235d58d0>,
#  'holm': <gensim.models.keyedvectors.Vocab at 0x1a235d5908>,
#  'iscsvax': <gensim.models.keyedvectors.Vocab at 0x1a235d5940>,
#  'uni': <gensim.models.keyedvectors.Vocab at 0x1a235d5978>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x1a235d59b0>,
#  'icon': <gensim.models.keyedvectors.Vocab at 0x1a235d59e8>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x1a235d5a20>,
#  'iowa': <gensim.models.keyedvectors.Vocab at 0x1a235d5a58>,
#  'download': <gensim.models.keyedvectors.Vocab at 0x1a235d5a90>,
#  'sever': <gensim.models.keyedvectors.Vocab at 0x1a235d5ac8>,
#  'bmp': <gensim.models.keyedvectors.Vocab at 0x1a235d5b00>,
#  'chang': <gensim.models.keyedvectors.Vocab at 0x1a235d5b38>,
#  'wallpap': <gensim.models.keyedvectors.Vocab at 0x1a235d5b70>,
#  'appreci': <gensim.models.keyedvectors.Vocab at 0x1a235d5ba8>,
#  'thanx': <gensim.models.keyedvectors.Vocab at 0x1a235d5be0>,
#  'ps': <gensim.models.keyedvectors.Vocab at 0x1a235d5c18>,
#  'kerr': <gensim.models.keyedvectors.Vocab at 0x1a235d5c50>,
#  'ux': <gensim.models.keyedvectors.Vocab at 0x1a235d5c88>,
#  'cso': <gensim.models.keyedvectors.Vocab at 0x1a235d5cc0>,
#  'uiuc': <gensim.models.keyedvectors.Vocab at 0x1a235d5cf8>,
#  'stan': <gensim.models.keyedvectors.Vocab at 0x1a235d5d30>,
#  'sigma': <gensim.models.keyedvectors.Vocab at 0x1a235d5d68>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x1a235d5da0>,
#  'doubl': <gensim.models.keyedvectors.Vocab at 0x1a235d5dd8>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x1a235d5e10>,
#  'illinoi': <gensim.models.keyedvectors.Vocab at 0x1a235d5e48>,
#  'urbana': <gensim.models.keyedvectors.Vocab at 0x1a235d5e80>,
#  'jap': <gensim.models.keyedvectors.Vocab at 0x1a235d5eb8>,
#  'po': <gensim.models.keyedvectors.Vocab at 0x1a235d5ef0>,
#  'cwru': <gensim.models.keyedvectors.Vocab at 0x1a235d5f28>,
#  'joseph': <gensim.models.keyedvectors.Vocab at 0x1a235d5f60>,
#  'pellettier': <gensim.models.keyedvectors.Vocab at 0x1a235d5f98>,
#  'board': <gensim.models.keyedvectors.Vocab at 0x1a235d5fd0>,
#  'hardwar': <gensim.models.keyedvectors.Vocab at 0x1a235d9048>,
#  'compress': <gensim.models.keyedvectors.Vocab at 0x1a235d9080>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x1a235d90b8>,
#  'autodoubl': <gensim.models.keyedvectors.Vocab at 0x1a235d90f0>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x1a235d9128>,
#  'diskdoubl': <gensim.models.keyedvectors.Vocab at 0x1a235d9160>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x1a235d9198>,
#  'licens': <gensim.models.keyedvectors.Vocab at 0x1a235d91d0>,
#  'stac': <gensim.models.keyedvectors.Vocab at 0x1a235d9208>,
#  'technolog': <gensim.models.keyedvectors.Vocab at 0x1a235d9240>,
#  'owner': <gensim.models.keyedvectors.Vocab at 0x1a235d9278>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x1a235d92b0>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x1a235d92e8>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x1a235d9320>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x1a235d9358>,
#  'someth': <gensim.models.keyedvectors.Vocab at 0x1a235d9390>,
#  'els': <gensim.models.keyedvectors.Vocab at 0x1a235d93c8>,
#  'howev': <gensim.models.keyedvectors.Vocab at 0x1a235d9400>,
#  'decompress': <gensim.models.keyedvectors.Vocab at 0x1a235d9438>,
#  'troubl': <gensim.models.keyedvectors.Vocab at 0x1a235d9470>,
#  'recompress': <gensim.models.keyedvectors.Vocab at 0x1a235d94a8>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x1a235d94e0>,
#  'usual': <gensim.models.keyedvectors.Vocab at 0x1a235d9518>,
#  'reappear': <gensim.models.keyedvectors.Vocab at 0x1a235d9550>,
#  'mention': <gensim.models.keyedvectors.Vocab at 0x1a235d9588>,
#  'freewar': <gensim.models.keyedvectors.Vocab at 0x1a235d95c0>,
#  'expans': <gensim.models.keyedvectors.Vocab at 0x1a235d95f8>,
#  'util': <gensim.models.keyedvectors.Vocab at 0x1a235d9630>,
#  'dd': <gensim.models.keyedvectors.Vocab at 0x1a235d9668>,
#  'expand': <gensim.models.keyedvectors.Vocab at 0x1a235d96a0>,
#  'unless': <gensim.models.keyedvectors.Vocab at 0x1a235d96d8>,
#  'unlik': <gensim.models.keyedvectors.Vocab at 0x1a235d9710>,
#  'hole': <gensim.models.keyedvectors.Vocab at 0x1a235d9748>,
#  'relat': <gensim.models.keyedvectors.Vocab at 0x1a235d9780>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x1a235d97b8>,
#  'reluct': <gensim.models.keyedvectors.Vocab at 0x1a235d97f0>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x1a235d9828>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x1a235d9860>,
#  'competit': <gensim.models.keyedvectors.Vocab at 0x1a235d9898>,
#  'commun': <gensim.models.keyedvectors.Vocab at 0x1a235d98d0>,
#  'servic': <gensim.models.keyedvectors.Vocab at 0x1a235d9908>,
#  'offic': <gensim.models.keyedvectors.Vocab at 0x1a235d9940>,
#  'stankerr': <gensim.models.keyedvectors.Vocab at 0x1a235d9978>,
#  'irwin': <gensim.models.keyedvectors.Vocab at 0x1a235d99b0>,
#  'cmptrc': <gensim.models.keyedvectors.Vocab at 0x1a235d99e8>,
#  'lonestar': <gensim.models.keyedvectors.Vocab at 0x1a235d9a20>,
#  'org': <gensim.models.keyedvectors.Vocab at 0x1a235d9a58>,
#  'arnstein': <gensim.models.keyedvectors.Vocab at 0x1a235d9a90>,
#  'recommend': <gensim.models.keyedvectors.Vocab at 0x1a235d9ac8>,
#  'duc': <gensim.models.keyedvectors.Vocab at 0x1a235d9b00>,
#  'expir': <gensim.models.keyedvectors.Vocab at 0x1a235d9b38>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x1a235d9b70>,
#  'gmt': <gensim.models.keyedvectors.Vocab at 0x1a235d9ba8>,
#  'computrac': <gensim.models.keyedvectors.Vocab at 0x1a235d9be0>,
#  'inc': <gensim.models.keyedvectors.Vocab at 0x1a235d9c18>,
#  'richardson': <gensim.models.keyedvectors.Vocab at 0x1a235d9c50>,
#  'tx': <gensim.models.keyedvectors.Vocab at 0x1a235d9c88>,
#  'ducati': <gensim.models.keyedvectors.Vocab at 0x1a235d9cc0>,
#  'gt': <gensim.models.keyedvectors.Vocab at 0x1a235d9cf8>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x1a235d9d30>,
#  'paint': <gensim.models.keyedvectors.Vocab at 0x1a235d9d68>,
#  'bronz': <gensim.models.keyedvectors.Vocab at 0x1a235d9da0>,
#  'brown': <gensim.models.keyedvectors.Vocab at 0x1a235d9dd8>,
#  'orang': <gensim.models.keyedvectors.Vocab at 0x1a235d9e10>,
#  'fade': <gensim.models.keyedvectors.Vocab at 0x1a235d9e48>,
#  'leak': <gensim.models.keyedvectors.Vocab at 0x1a235d9e80>,
#  'oil': <gensim.models.keyedvectors.Vocab at 0x1a235d9eb8>,
#  'pop': <gensim.models.keyedvectors.Vocab at 0x1a235d9ef0>,
#  'st': <gensim.models.keyedvectors.Vocab at 0x1a235d9f28>,
#  'accel': <gensim.models.keyedvectors.Vocab at 0x1a235d9f60>,
#  'shop': <gensim.models.keyedvectors.Vocab at 0x1a235d9f98>,
#  'tran': <gensim.models.keyedvectors.Vocab at 0x1a235d9fd0>,
#  'sold': <gensim.models.keyedvectors.Vocab at 0x1a235dc048>,
#  'bike': <gensim.models.keyedvectors.Vocab at 0x1a235dc080>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x1a235dc0b8>,
#  'stabl': <gensim.models.keyedvectors.Vocab at 0x1a235dc0f0>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x1a235dc128>,
#  'beemer': <gensim.models.keyedvectors.Vocab at 0x1a235dc160>,
#  'axi': <gensim.models.keyedvectors.Vocab at 0x1a235dc198>,
#  'motor': <gensim.models.keyedvectors.Vocab at 0x1a235dc1d0>,
#  'tuba': <gensim.models.keyedvectors.Vocab at 0x1a235dc208>,
#  'honk': <gensim.models.keyedvectors.Vocab at 0x1a235dc240>,
#  'therefor': <gensim.models.keyedvectors.Vocab at 0x1a235dc278>,
#  'dod': <gensim.models.keyedvectors.Vocab at 0x1a235dc2b0>,
#  'david': <gensim.models.keyedvectors.Vocab at 0x1a235dc2e8>,
#  'terminu': <gensim.models.keyedvectors.Vocab at 0x1a235dc320>,
#  'ericsson': <gensim.models.keyedvectors.Vocab at 0x1a235dc358>,
#  'se': <gensim.models.keyedvectors.Vocab at 0x1a235dc390>,
#  'bold': <gensim.models.keyedvectors.Vocab at 0x1a235dc3c8>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x1a235dc400>,
#  'moral': <gensim.models.keyedvectors.Vocab at 0x1a235dc438>,
#  'camtec': <gensim.models.keyedvectors.Vocab at 0x1a235dc470>,
#  'electron': <gensim.models.keyedvectors.Vocab at 0x1a235dc4a8>,
#  'leicest': <gensim.models.keyedvectors.Vocab at 0x1a235dc4e0>,
#  'england': <gensim.models.keyedvectors.Vocab at 0x1a235dc518>,
#  'bangkok': <gensim.models.keyedvectors.Vocab at 0x1a235dc550>,
#  'freenet': <gensim.models.keyedvectors.Vocab at 0x1a235dc588>,
#  'carleton': <gensim.models.keyedvectors.Vocab at 0x1a235dc5c0>,
#  'ca': <gensim.models.keyedvectors.Vocab at 0x1a235dc5f8>,
#  'ad': <gensim.models.keyedvectors.Vocab at 0x1a235dc630>,
#  'jame': <gensim.models.keyedvectors.Vocab at 0x1a235dc668>,
#  'owen': <gensim.models.keyedvectors.Vocab at 0x1a235dc6a0>,
#  'previou': <gensim.models.keyedvectors.Vocab at 0x1a235dc6d8>,
#  'rude': <gensim.models.keyedvectors.Vocab at 0x1a235dc710>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x1a235dc748>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x1a235dc780>,
#  'differ': <gensim.models.keyedvectors.Vocab at 0x1a235dc7b8>,
#  'stick': <gensim.models.keyedvectors.Vocab at 0x1a235dc7f0>,
#  'intent': <gensim.models.keyedvectors.Vocab at 0x1a235dc828>,
#  'explain': <gensim.models.keyedvectors.Vocab at 0x1a235dc860>,
#  'jung': <gensim.models.keyedvectors.Vocab at 0x1a235dc898>,
#  'god': <gensim.models.keyedvectors.Vocab at 0x1a235dc8d0>,
#  'overlook': <gensim.models.keyedvectors.Vocab at 0x1a235dc908>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x1a235dc940>,
#  'unknow': <gensim.models.keyedvectors.Vocab at 0x1a235dc978>,
#  'yep': <gensim.models.keyedvectors.Vocab at 0x1a235dc9b0>,
#  'jew': <gensim.models.keyedvectors.Vocab at 0x1a235dc9e8>,
#  'jewish': <gensim.models.keyedvectors.Vocab at 0x1a235dca20>,
#  'coven': <gensim.models.keyedvectors.Vocab at 0x1a235dca58>,
#  'yhwh': <gensim.models.keyedvectors.Vocab at 0x1a235dca90>,
#  'patriarch': <gensim.models.keyedvectors.Vocab at 0x1a235dcac8>,
#  'abraham': <gensim.models.keyedvectors.Vocab at 0x1a235dcb00>,
#  'mose': <gensim.models.keyedvectors.Vocab at 0x1a235dcb38>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x1a235dcb70>,
#  'establish': <gensim.models.keyedvectors.Vocab at 0x1a235dcba8>,
#  'mankind': <gensim.models.keyedvectors.Vocab at 0x1a235dcbe0>,
#  'decid': <gensim.models.keyedvectors.Vocab at 0x1a235dcc18>,
#  'boundari': <gensim.models.keyedvectors.Vocab at 0x1a235dcc50>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x1a235dcc88>,
#  'sadduce': <gensim.models.keyedvectors.Vocab at 0x1a235dccc0>,
#  'torah': <gensim.models.keyedvectors.Vocab at 0x1a235dccf8>,
#  'wherea': <gensim.models.keyedvectors.Vocab at 0x1a235dcd30>,
#  'pharise': <gensim.models.keyedvectors.Vocab at 0x1a235dcd68>,
#  'ancestor': <gensim.models.keyedvectors.Vocab at 0x1a235dcda0>,
#  'judaism': <gensim.models.keyedvectors.Vocab at 0x1a235dcdd8>,
#  'interpret': <gensim.models.keyedvectors.Vocab at 0x1a235dce10>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x1a235dce48>,
#  'nuanc': <gensim.models.keyedvectors.Vocab at 0x1a235dce80>,
#  'talmud': <gensim.models.keyedvectors.Vocab at 0x1a235dceb8>,
#  'essenc': <gensim.models.keyedvectors.Vocab at 0x1a235dcef0>,
#  'biblic': <gensim.models.keyedvectors.Vocab at 0x1a235dcf28>,
#  'christian': <gensim.models.keyedvectors.Vocab at 0x1a235dcf60>,
#  'necessarili': <gensim.models.keyedvectors.Vocab at 0x1a235dcf98>,
#  'indic': <gensim.models.keyedvectors.Vocab at 0x1a235dcfd0>,
#  'anyth': <gensim.models.keyedvectors.Vocab at 0x1a235e0048>,
#  'outsid': <gensim.models.keyedvectors.Vocab at 0x1a235e0080>,
#  'relationship': <gensim.models.keyedvectors.Vocab at 0x1a235e00b8>,
#  'specul': <gensim.models.keyedvectors.Vocab at 0x1a235e00f0>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x1a235e0128>,
#  'creat': <gensim.models.keyedvectors.Vocab at 0x1a235e0160>,
#  'imag': <gensim.models.keyedvectors.Vocab at 0x1a235e0198>,
#  'commit': <gensim.models.keyedvectors.Vocab at 0x1a235e01d0>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x1a235e0208>,
#  'christ': <gensim.models.keyedvectors.Vocab at 0x1a235e0240>,
#  'exampl': <gensim.models.keyedvectors.Vocab at 0x1a235e0278>,
#  'press': <gensim.models.keyedvectors.Vocab at 0x1a235e02b0>,
#  'argu': <gensim.models.keyedvectors.Vocab at 0x1a235e02e8>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x1a235e0320>,
#  'conclus': <gensim.models.keyedvectors.Vocab at 0x1a235e0358>,
#  'upset': <gensim.models.keyedvectors.Vocab at 0x1a235e0390>,
#  'cart': <gensim.models.keyedvectors.Vocab at 0x1a235e03c8>,
#  'script': <gensim.models.keyedvectors.Vocab at 0x1a235e0400>,
#  'shaki': <gensim.models.keyedvectors.Vocab at 0x1a235e0438>,
#  'foundat': <gensim.models.keyedvectors.Vocab at 0x1a235e0470>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x1a235e04a8>,
#  'metaphor': <gensim.models.keyedvectors.Vocab at 0x1a235e04e0>,
#  'littl': <gensim.models.keyedvectors.Vocab at 0x1a235e0518>,
#  'jesu': <gensim.models.keyedvectors.Vocab at 0x1a235e0550>,
#  'record': <gensim.models.keyedvectors.Vocab at 0x1a235e0588>,
#  'utter': <gensim.models.keyedvectors.Vocab at 0x1a235e05c0>,
#  'narr': <gensim.models.keyedvectors.Vocab at 0x1a235e05f8>,
#  'historian': <gensim.models.keyedvectors.Vocab at 0x1a235e0630>,
#  'revel': <gensim.models.keyedvectors.Vocab at 0x1a235e0668>,
#  'asid': <gensim.models.keyedvectors.Vocab at 0x1a235e06a0>,
#  'wors': <gensim.models.keyedvectors.Vocab at 0x1a235e06d8>,
#  'attempt': <gensim.models.keyedvectors.Vocab at 0x1a235e0710>,
#  'debunk': <gensim.models.keyedvectors.Vocab at 0x1a235e0748>,
#  'initi': <gensim.models.keyedvectors.Vocab at 0x1a235e0780>,
#  'bibl': <gensim.models.keyedvectors.Vocab at 0x1a235e07b8>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x1a235e07f0>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x1a235e0828>,
#  'faith': <gensim.models.keyedvectors.Vocab at 0x1a235e0860>,
#  'relev': <gensim.models.keyedvectors.Vocab at 0x1a235e0898>,
#  'inher': <gensim.models.keyedvectors.Vocab at 0x1a235e08d0>,
#  'metaphys': <gensim.models.keyedvectors.Vocab at 0x1a235e0908>,
#  'multipl': <gensim.models.keyedvectors.Vocab at 0x1a235e0940>,
#  'absolut': <gensim.models.keyedvectors.Vocab at 0x1a235e0978>,
#  'theolog': <gensim.models.keyedvectors.Vocab at 0x1a235e09b0>,
#  'undoubt': <gensim.models.keyedvectors.Vocab at 0x1a235e09e8>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x1a235e0a20>,
#  'parent': <gensim.models.keyedvectors.Vocab at 0x1a235e0a58>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x1a235e0a90>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x1a235e0ac8>,
#  'swear': <gensim.models.keyedvectors.Vocab at 0x1a235e0b00>,
#  'assum': <gensim.models.keyedvectors.Vocab at 0x1a235e0b38>,
#  'simpli': <gensim.models.keyedvectors.Vocab at 0x1a235e0b70>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x1a235e0ba8>,
#  'trooper': <gensim.models.keyedvectors.Vocab at 0x1a235e0be0>,
#  'pub': <gensim.models.keyedvectors.Vocab at 0x1a235e0c18>,
#  'bar': <gensim.models.keyedvectors.Vocab at 0x1a235e0c50>,
#  'children': <gensim.models.keyedvectors.Vocab at 0x1a235e0c88>,
#  'disobey': <gensim.models.keyedvectors.Vocab at 0x1a235e0cc0>,
#  'inappropri': <gensim.models.keyedvectors.Vocab at 0x1a235e0cf8>,
#  'quit': <gensim.models.keyedvectors.Vocab at 0x1a235e0d30>,
#  'happi': <gensim.models.keyedvectors.Vocab at 0x1a235e0d68>,
#  'anim': <gensim.models.keyedvectors.Vocab at 0x1a235e0da0>,
#  'analog': <gensim.models.keyedvectors.Vocab at 0x1a235e0dd8>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x1a235e0e10>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x1a235e0e48>,
#  'gist': <gensim.models.keyedvectors.Vocab at 0x1a235e0e80>,
#  'incident': <gensim.models.keyedvectors.Vocab at 0x1a235e0eb8>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x1a235e0ef0>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x1a235e0f28>,
#  'older': <gensim.models.keyedvectors.Vocab at 0x1a235e0f60>,
#  'piaget': <gensim.models.keyedvectors.Vocab at 0x1a235e0f98>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x1a235e0fd0>,
#  'religion': <gensim.models.keyedvectors.Vocab at 0x1a235e4048>,
#  'oh': <gensim.models.keyedvectors.Vocab at 0x1a235e4080>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x1a235e40b8>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x1a235e40f0>,
#  'cri': <gensim.models.keyedvectors.Vocab at 0x1a235e4128>,
#  'swam': <gensim.models.keyedvectors.Vocab at 0x1a235e4160>,
#  'rodc': <gensim.models.keyedvectors.Vocab at 0x1a235e4198>,
#  'fc': <gensim.models.keyedvectors.Vocab at 0x1a235e41d0>,
#  'hp': <gensim.models.keyedvectors.Vocab at 0x1a235e4208>,
#  'rod': <gensim.models.keyedvectors.Vocab at 0x1a235e4240>,
#  'cerkoney': <gensim.models.keyedvectors.Vocab at 0x1a235e4278>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x1a235e42b0>,
#  'qxf': <gensim.models.keyedvectors.Vocab at 0x1a235e42e8>,
#  'hewlett': <gensim.models.keyedvectors.Vocab at 0x1a235e4320>,
#  'packard': <gensim.models.keyedvectors.Vocab at 0x1a235e4358>,
#  'fort': <gensim.models.keyedvectors.Vocab at 0x1a235e4390>,
#  'collin': <gensim.models.keyedvectors.Vocab at 0x1a235e43c8>,
#  'co': <gensim.models.keyedvectors.Vocab at 0x1a235e4400>,
#  'regard': <gensim.models.keyedvectors.Vocab at 0x1a235e4438>,
#  'ms': <gensim.models.keyedvectors.Vocab at 0x1a235e4470>,
#  'east': <gensim.models.keyedvectors.Vocab at 0x1a235e44a8>,
#  'harmoni': <gensim.models.keyedvectors.Vocab at 0x1a235e44e0>,
#  'rd': <gensim.models.keyedvectors.Vocab at 0x1a235e4518>,
#  'hpdesk': <gensim.models.keyedvectors.Vocab at 0x1a235e4550>,
#  'dbm': <gensim.models.keyedvectors.Vocab at 0x1a235e4588>,
#  'tm': <gensim.models.keyedvectors.Vocab at 0x1a235e45c0>,
#  'lerc': <gensim.models.keyedvectors.Vocab at 0x1a235e45f8>,
#  'nasa': <gensim.models.keyedvectors.Vocab at 0x1a235e4630>,
#  'gov': <gensim.models.keyedvectors.Vocab at 0x1a235e4668>,
#  'mckissock': <gensim.models.keyedvectors.Vocab at 0x1a235e46a0>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x1a235e46d8>,
#  'station': <gensim.models.keyedvectors.Vocab at 0x1a235e4710>,
#  'redesign': <gensim.models.keyedvectors.Vocab at 0x1a235e4748>,
#  'jsc': <gensim.models.keyedvectors.Vocab at 0x1a235e4780>,
#  'altern': <gensim.models.keyedvectors.Vocab at 0x1a235e47b8>,
#  'lewi': <gensim.models.keyedvectors.Vocab at 0x1a235e47f0>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x1a235e4828>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x1a235e4860>,
#  'cleveland': <gensim.models.keyedvectors.Vocab at 0x1a235e4898>,
#  'ohio': <gensim.models.keyedvectors.Vocab at 0x1a235e48d0>,
#  'vax': <gensim.models.keyedvectors.Vocab at 0x1a235e4908>,
#  'vm': <gensim.models.keyedvectors.Vocab at 0x1a235e4940>,
#  'vnew': <gensim.models.keyedvectors.Vocab at 0x1a235e4978>,
#  'aio': <gensim.models.keyedvectors.Vocab at 0x1a235e49b0>,
#  'kjenk': <gensim.models.keyedvectors.Vocab at 0x1a235e49e8>,
#  'gothamc': <gensim.models.keyedvectors.Vocab at 0x1a235e4a20>,
#  'descript': <gensim.models.keyedvectors.Vocab at 0x1a235e4a58>,
#  'extern': <gensim.models.keyedvectors.Vocab at 0x1a235e4a90>,
#  'tank': <gensim.models.keyedvectors.Vocab at 0x1a235e4ac8>,
#  'option': <gensim.models.keyedvectors.Vocab at 0x1a235e4b00>,
#  'ssf': <gensim.models.keyedvectors.Vocab at 0x1a235e4b38>,
#  'mark': <gensim.models.keyedvectors.Vocab at 0x1a235e4b70>,
#  'propos': <gensim.models.keyedvectors.Vocab at 0x1a235e4ba8>,
#  'shea': <gensim.models.keyedvectors.Vocab at 0x1a235e4be0>,
#  'committe': <gensim.models.keyedvectors.Vocab at 0x1a235e4c18>,
#  'crystal': <gensim.models.keyedvectors.Vocab at 0x1a235e4c50>,
#  'citi': <gensim.models.keyedvectors.Vocab at 0x1a235e4c88>,
#  'warmli': <gensim.models.keyedvectors.Vocab at 0x1a235e4cc0>,
#  'receiv': <gensim.models.keyedvectors.Vocab at 0x1a235e4cf8>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x1a235e4d30>,
#  'wingless': <gensim.models.keyedvectors.Vocab at 0x1a235e4d68>,
#  'orbit': <gensim.models.keyedvectors.Vocab at 0x1a235e4da0>,
#  'yo': <gensim.models.keyedvectors.Vocab at 0x1a235e4dd8>,
#  'ken': <gensim.models.keyedvectors.Vocab at 0x1a235e4e10>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x1a235e4e48>,
#  'edit': <gensim.models.keyedvectors.Vocab at 0x1a235e4e80>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x1a235e4eb8>,
#  'connor': <gensim.models.keyedvectors.Vocab at 0x1a235e4ef0>,
#  'panel': <gensim.models.keyedvectors.Vocab at 0x1a235e4f28>,
#  'giant': <gensim.models.keyedvectors.Vocab at 0x1a235e4f60>,
#  'fuel': <gensim.models.keyedvectors.Vocab at 0x1a235e4f98>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x1a235e4fd0>,
#  'wing': <gensim.models.keyedvectors.Vocab at 0x1a235e8048>,
#  'tail': <gensim.models.keyedvectors.Vocab at 0x1a235e8080>,
#  'remov': <gensim.models.keyedvectors.Vocab at 0x1a235e80b8>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x1a235e80f0>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x1a235e8128>,
#  'advisori': <gensim.models.keyedvectors.Vocab at 0x1a235e8160>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x1a235e8198>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x1a235e81d0>,
#  'modular': <gensim.models.keyedvectors.Vocab at 0x1a235e8208>,
#  'approach': <gensim.models.keyedvectors.Vocab at 0x1a235e8240>,
#  'studi': <gensim.models.keyedvectors.Vocab at 0x1a235e8278>,
#  'team': <gensim.models.keyedvectors.Vocab at 0x1a235e82b0>,
#  'msfc': <gensim.models.keyedvectors.Vocab at 0x1a235e82e8>,
#  'larc': <gensim.models.keyedvectors.Vocab at 0x1a235e8320>,
#  'srt': <gensim.models.keyedvectors.Vocab at 0x1a235e8358>,
#  'reston': <gensim.models.keyedvectors.Vocab at 0x1a235e8390>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x1a235e83c8>,
#  'locat': <gensim.models.keyedvectors.Vocab at 0x1a235e8400>,
#  'respect': <gensim.models.keyedvectors.Vocab at 0x1a235e8438>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x1a235e8470>,
#  'featur': <gensim.models.keyedvectors.Vocab at 0x1a235e84a8>,
#  'bu': <gensim.models.keyedvectors.Vocab at 0x1a235e84e0>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x1a235e8518>,
#  'lockhe': <gensim.models.keyedvectors.Vocab at 0x1a235e8550>,
#  'qualifi': <gensim.models.keyedvectors.Vocab at 0x1a235e8588>,
#  'elv': <gensim.models.keyedvectors.Vocab at 0x1a235e85c0>,
#  'provid': <gensim.models.keyedvectors.Vocab at 0x1a235e85f8>,
#  'propuls': <gensim.models.keyedvectors.Vocab at 0x1a235e8630>,
#  'gn': <gensim.models.keyedvectors.Vocab at 0x1a235e8668>,
#  'manag': <gensim.models.keyedvectors.Vocab at 0x1a235e86a0>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x1a235e86d8>,
#  'forc': <gensim.models.keyedvectors.Vocab at 0x1a235e8710>,
#  'capabl': <gensim.models.keyedvectors.Vocab at 0x1a235e8748>,
#  'obtain': <gensim.models.keyedvectors.Vocab at 0x1a235e8780>,
#  'flight': <gensim.models.keyedvectors.Vocab at 0x1a235e87b8>,
#  'solar': <gensim.models.keyedvectors.Vocab at 0x1a235e87f0>,
#  'array': <gensim.models.keyedvectors.Vocab at 0x1a235e8828>,
#  'kw': <gensim.models.keyedvectors.Vocab at 0x1a235e8860>,
#  'vehicl': <gensim.models.keyedvectors.Vocab at 0x1a235e8898>,
#  'fli': <gensim.models.keyedvectors.Vocab at 0x1a235e88d0>,
#  'arrow': <gensim.models.keyedvectors.Vocab at 0x1a235e8908>,
#  'optim': <gensim.models.keyedvectors.Vocab at 0x1a235e8940>,
#  'micrograv': <gensim.models.keyedvectors.Vocab at 0x1a235e8978>,
#  'environ': <gensim.models.keyedvectors.Vocab at 0x1a235e89b0>,
#  'spacelab': <gensim.models.keyedvectors.Vocab at 0x1a235e89e8>,
#  'mission': <gensim.models.keyedvectors.Vocab at 0x1a235e8a20>,
#  'sourc': <gensim.models.keyedvectors.Vocab at 0x1a235e8a58>,
#  'tend': <gensim.models.keyedvectors.Vocab at 0x1a235e8a90>,
#  'oppos': <gensim.models.keyedvectors.Vocab at 0x1a235e8ac8>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x1a235e8b00>,
#  'sexist': <gensim.models.keyedvectors.Vocab at 0x1a235e8b38>,
#  'achiev': <gensim.models.keyedvectors.Vocab at 0x1a235e8b70>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x1a235e8ba8>,
#  'modul': <gensim.models.keyedvectors.Vocab at 0x1a235e8be0>,
#  'modifi': <gensim.models.keyedvectors.Vocab at 0x1a235e8c18>,
#  'lab': <gensim.models.keyedvectors.Vocab at 0x1a235e8c50>,
#  'dock': <gensim.models.keyedvectors.Vocab at 0x1a235e8c88>,
#  'port': <gensim.models.keyedvectors.Vocab at 0x1a235e8cc0>,
#  'intern': <gensim.models.keyedvectors.Vocab at 0x1a235e8cf8>,
#  'partner': <gensim.models.keyedvectors.Vocab at 0x1a235e8d30>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x1a235e8d68>,
#  'node': <gensim.models.keyedvectors.Vocab at 0x1a235e8da0>,
#  'habit': <gensim.models.keyedvectors.Vocab at 0x1a235e8dd8>,
#  'eva': <gensim.models.keyedvectors.Vocab at 0x1a235e8e10>,
#  'nasda': <gensim.models.keyedvectors.Vocab at 0x1a235e8e48>,
#  'esa': <gensim.models.keyedvectors.Vocab at 0x1a235e8e80>,
#  'perman': <gensim.models.keyedvectors.Vocab at 0x1a235e8eb8>,
#  'presenc': <gensim.models.keyedvectors.Vocab at 0x1a235e8ef0>,
#  'acrv': <gensim.models.keyedvectors.Vocab at 0x1a235e8f28>,
#  'assur': <gensim.models.keyedvectors.Vocab at 0x1a235e8f60>,
#  'return': <gensim.models.keyedvectors.Vocab at 0x1a235e8f98>,
#  'freedom': <gensim.models.keyedvectors.Vocab at 0x1a235e8fd0>,
#  'deriv': <gensim.models.keyedvectors.Vocab at 0x1a235ea048>,
#  'mike': <gensim.models.keyedvectors.Vocab at 0x1a235ea080>,
#  'griffin': <gensim.models.keyedvectors.Vocab at 0x1a235ea0b8>,
#  'alot': <gensim.models.keyedvectors.Vocab at 0x1a235ea0f0>,
#  'lightweight': <gensim.models.keyedvectors.Vocab at 0x1a235ea128>,
#  'assembl': <gensim.models.keyedvectors.Vocab at 0x1a235ea160>,
#  'inclin': <gensim.models.keyedvectors.Vocab at 0x1a235ea198>,
#  'occur': <gensim.models.keyedvectors.Vocab at 0x1a235ea1d0>,
#  ...}

# %% [markdown]
# This is the vector for the word "car":

# %%
model.wv['car']
# Out:
# array([ 0.48168394,  0.58812076,  3.3706393 , -0.1423689 ,  3.3050134 ,
#         3.076569  , -4.221543  ,  1.4831884 ,  2.164517  ,  2.5697005 ,
#         0.6336334 ,  0.5374686 ,  3.9173477 ,  1.2986215 ,  2.155824  ,
#        -0.28841922,  2.8315086 , -1.0542144 , -2.8753872 , -3.1601791 ,
#        -2.944351  ,  3.3646429 ,  0.70514286,  0.6503262 , -1.0394558 ,
#         1.6471945 , -0.27621242,  0.21327908,  3.52527   , -0.5307024 ,
#        -2.804661  ,  0.9072769 , -3.1328914 , -1.7292366 ,  0.36830965,
#         2.1848297 , -1.6726061 , -1.0553693 , -2.1336393 ,  0.1097566 ,
#         2.8939824 , -0.26097524,  4.0498776 , -0.3719951 ,  0.4365983 ,
#        -1.3117374 , -2.969182  , -2.1095781 ,  0.10295936,  3.6426418 ,
#         2.1645617 , -0.7936139 ,  0.31238562,  0.9756818 ,  3.1398711 ,
#        -8.522598  , -1.5727097 , -0.9947048 , -3.379533  , -2.6543257 ,
#        -6.1201386 ,  1.8999187 ,  1.7206688 , -1.831763  , -0.10841425,
#        -1.6270516 ,  0.8015438 ,  2.4489594 ,  3.5294902 ,  3.2274446 ,
#         1.3699071 ,  0.51245624,  3.7676945 , -1.288102  , -2.379082  ,
#        -0.37922725,  1.7881957 , -1.7910806 ,  1.8886815 , -2.2008133 ,
#         1.8683101 , -0.19989294,  2.641028  , -2.2457027 , -0.21261363,
#        -0.94678396, -3.378002  ,  2.5514364 , -6.697377  , -5.892589  ,
#         1.1676388 ,  1.2960604 , -1.5399001 , -5.269859  ,  3.4358597 ,
#        -1.4297361 ,  2.1448212 , -1.360872  ,  2.3456938 , -3.3564734 ],
#       dtype=float32)

# %% [markdown]
# Now let's try to look up words similar to the word "car"

# %%
model.wv.similar_by_word('car', topn = 5)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('sedan', 0.6838402152061462),
#  ('driven', 0.673595130443573),
#  ('porsch', 0.6728496551513672),
#  ('wagon', 0.6658891439437866),
#  ('toyota', 0.65086829662323)]

# %% [markdown]
# ### Similarity between two words in the vocabulary

# %% [markdown]
# We can also use the Word2Vec model to return the similarity between two words that are present in the vocabulary.

# %%
model.wv.similarity(w1="car",w2="bike")
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.52340454

# %%
model.wv.similarity(w1="car",w2="car")
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 1.0

# %%
model.wv.similarity(w1="car",w2="hard")
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.14325282

# %% [markdown]
# ## Bag of Words
# Now let's have a look at the BoW model. In some situations, using BoW may be better than Word Embedding, for example:
# 1. Building an baseline model. By using scikit-learn, you need just a few lines of code to build model.
# 2. If your dataset is small and context is domain specific. Context is very domain specific means that you cannot find corresponding Vector from pre-trained word embedding models (GloVe, fastText etc).

# %% [markdown]
# Below are some simple ways to build BoW models:

# %% [markdown]
# ## Count Occurrences
# Counting word occurrences. The reason behind using this approach is that keywords or important signals occur repeatedly. So the number of occurrences can represent the importance of word. For example:

# %%
# example sentence
doc = "In the-state-of-art of the NLP field, Embedding is the \
success way to resolve text related problem and outperform \
Bag of Words ( BoW ). Indeed, BoW introduced limitations \
large feature dimension, sparse representation etc."

# %%
# Initialize a CountVectorizer object
count_vec = CountVectorizer()

# Transforms the data into a bag of words (sparse matrix)
count_occurs = count_vec.fit_transform([doc])

# Create a table to count occurrences of each word
count_occur_df = pd.DataFrame((count, word) for word, count in 
                              zip(count_occurs.toarray().tolist()[0], count_vec.get_feature_names()))
count_occur_df.columns = ['Word', 'Count']
count_occur_df.sort_values('Count', ascending=False, inplace=True)
count_occur_df.head(10)
# Out:
#        Word  Count
# 16       of      3
# 26      the      3
# 3       bow      2
# 0       and      1
# 28      way      1
# 27       to      1
# 25     text      1
# 24  success      1
# 23    state      1
# 22   sparse      1

# %% [markdown]
# ## Normalized Count Occurrences
# Normalization can be applied to avoid model bias. For example:

# %%
# Initialize a TfidfVectorizer object
norm_count_vec = TfidfVectorizer(use_idf=False, norm='l2')

# Transforms the data into a bag of words (sparse matrix)
norm_count_occurs = norm_count_vec.fit_transform([doc])

# Create a table to count occurrences of each word
norm_count_occur_df = pd.DataFrame((count, word) for word, count in 
                                   zip(norm_count_occurs.toarray().tolist()[0], norm_count_vec.get_feature_names()))
norm_count_occur_df.columns = ['Word', 'Count']
norm_count_occur_df.sort_values('Count', ascending=False, inplace=True)
norm_count_occur_df.head(10)
# Out:
#        Word     Count
# 16       of  0.428571
# 26      the  0.428571
# 3       bow  0.285714
# 0       and  0.142857
# 28      way  0.142857
# 27       to  0.142857
# 25     text  0.142857
# 24  success  0.142857
# 23    state  0.142857
# 22   sparse  0.142857

# %% [markdown]
# ## TF-IDF
# TF-IDF take another approach which is believe that high frequency may not able to provide much information gain. In another word, rare words contribute more weights to the model.
# Word importance will be increased if the number of occurrence within same document (i.e. training record). On the other hand, it will be decreased if it occurs in corpus (i.e. other training records).

# %%
# Initialize a TfidfVectorizer object
tfidf_vec = TfidfVectorizer()

# Transforms the data into a bag of words (sparse matrix)
tfidf_count_occurs = tfidf_vec.fit_transform([doc])

# Create a table to count occurrences of each word
tfidf_count_occur_df = pd.DataFrame((count, word) for word, count in zip(
    tfidf_count_occurs.toarray().tolist()[0], tfidf_vec.get_feature_names()))
tfidf_count_occur_df.columns = ['Word', 'Count']
tfidf_count_occur_df.sort_values('Count', ascending=False, inplace=True)
tfidf_count_occur_df.head(10)
# Out:
#        Word     Count
# 16       of  0.428571
# 26      the  0.428571
# 3       bow  0.285714
# 0       and  0.142857
# 28      way  0.142857
# 27       to  0.142857
# 25     text  0.142857
# 24  success  0.142857
# 23    state  0.142857
# 22   sparse  0.142857

# %% [markdown]
# Now let's evaluate the two BoW models:

# %%
print('Using Count Vectorizer:')
model_pipeline = pipeline(x_train, y_train, mode='count')

print('\nUsing TF Vectorizer:')
model_pipeline = pipeline(x_train, y_train, mode='tf')

print('\nUsing TF-IDF Vectorizer------')
model_pipeline = pipeline(x_train, y_train, mode='tfidf')
# Out:
# Using Count Vectorizer:
# Accuracy: 0.8945 (+/- 0.0185)
#
# Using TF Vectorizer:
